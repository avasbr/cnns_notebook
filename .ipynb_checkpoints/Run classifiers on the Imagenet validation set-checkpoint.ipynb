# %%
import pandas as pd
import os
from scipy.io import loadmat
from cnns.utils import cnn_utils as cu
from cnns.utils import imagenet_utils as imu
import numpy as np
import json

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
evaluation_dir = '/Users/babasarala/Desktop/evaluation'
cnn_dir = '/Users/babasarala/repos/cnns'
image_url_files_dir = os.path.join(evaluation_dir, 'image_url_files')
mat_filepath = '%s/ILSVRC2013_devkit/data/meta_clsloc.mat'% evaluation_dir
ground_truth_filepath = os.path.join(evaluation_dir, 'raw_images/ILSVRC2013_clsloc_validation_ground_truth.txt')
results_dirpath = os.path.join(evaluation_dir, 'ILSVRC2012_val')
collapse_filepath = os.path.join(cnn_dir, 'config/imagenet_cats_2016_12_07.json')

# %%
# recover the label names
mappings = json.load(open(collapse_filepath, 'rb'))
cat_names = set([])
for imagenet_label, collapsed_cat in mappings.iteritems():
    cat_names.add(collapsed_cat)
cat_names = list(cat_names)

# %% [markdown]
# # Analyzing the ILSVR2012 Validation set with the different Neural Networks

# %%
def load_validation_ground_truth(ground_truth_filepath, mat_filepath, collapse_filepath=None):
    ground_truth_idxs = []
    img_urls = []
    with open(ground_truth_filepath, 'rb') as f:
        cnt = 0
        for idx, lines in enumerate(f):
            num_zeros = 8 - len(str(idx))
            img_urls.append('ILSVRC2012_val_%s%i.JPEG'%(''.join(['0']*num_zeros), idx+1))
            ground_truth_idxs.append(int(lines))
    ilsvrc_id_cats = imu.load_imagenet_cats_from_mat(mat_filepath)
    # k->v : image idx -> v
    ground_truth_cats = {img_url: ilsvrc_id_cats[img_idx]
                           for img_idx, img_url in zip(ground_truth_idxs, img_urls)}
    if collapse_filepath:
        tfm_fcn = cu.get_tfm_fcn_from_json(collapse_filepath)
        return {img_idx: tfm_fcn(ground_truth_cat)
                for img_idx, ground_truth_cat in ground_truth_cats.iteritems()}

    return ground_truth_cats

# %%
ground_truth_labels = load_validation_ground_truth(ground_truth_filepath, 
                                                   mat_filepath, 
                                                   collapse_filepath=None)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-12-108b76260c08> in <module>()
#       1 ground_truth_labels = load_validation_ground_truth(ground_truth_filepath,
#       2                                                    mat_filepath,
# ----> 3                                                    collapse_filepath=None)
#
# <ipython-input-11-4d27e750196f> in load_validation_ground_truth(ground_truth_filepath, mat_filepath, collapse_filepath)
#       8             img_urls.append('ILSVRC2012_val_%s%i.JPEG'%(''.join(['0']*num_zeros), idx+1))
#       9             ground_truth_idxs.append(int(lines))
# ---> 10     ilsvrc_id_cats = imu.load_imagenet_cats_from_mat(mat_filepath)
#      11     # k->v : image idx -> v
#      12     ground_truth_cats = {img_url: ilsvrc_id_cats[img_idx]
#
# /usr/local/lib/python2.7/site-packages/cnns/utils/imagenet_utils.pyc in load_imagenet_cats_from_mat(mat_filepath)
#     130 def load_imagenet_cats_from_mat(mat_filepath):
#     131     id_cat = {}
# --> 132     mat = loadmat(mat_filepath)
#     133     for i in range(NUM_CATS):
#     134         islvcr_id = mat['synsets'][0][i][0][0][0]
#
# /usr/local/lib/python2.7/site-packages/scipy/io/matlab/mio.pyc in loadmat(file_name, mdict, appendmat, **kwargs)
#     132     """
#     133     variable_names = kwargs.pop('variable_names', None)
# --> 134     MR = mat_reader_factory(file_name, appendmat, **kwargs)
#     135     matfile_dict = MR.get_variables(variable_names)
#     136     if mdict is not None:
#
# /usr/local/lib/python2.7/site-packages/scipy/io/matlab/mio.pyc in mat_reader_factory(file_name, appendmat, **kwargs)
#      55        type detected in `filename`.
#      56     """
# ---> 57     byte_stream = _open_file(file_name, appendmat)
#      58     mjv, mnv = get_matfile_version(byte_stream)
#      59     if mjv == 0:
#
# /usr/local/lib/python2.7/site-packages/scipy/io/matlab/mio.pyc in _open_file(file_like, appendmat)
#      21     if isinstance(file_like, string_types):
#      22         try:
# ---> 23             return open(file_like, 'rb')
#      24         except IOError as e:
#      25             if appendmat and not file_like.endswith('.mat'):
#
# IOError: [Errno 2] No such file or directory: '/Users/babasarala/Desktop/evaluation/data/meta_clsloc.mat'

# %%
ground_truth_labels
# Out:
# {'ILSVRC2012_val_00031598.JPEG': u'tree frog, tree-frog',
#  'ILSVRC2012_val_00014557.JPEG': u'chiffonier, commode',
#  'ILSVRC2012_val_00038370.JPEG': u'remote control, remote',
#  'ILSVRC2012_val_00033013.JPEG': u'space shuttle',
#  'ILSVRC2012_val_00017040.JPEG': u'tractor',
#  'ILSVRC2012_val_00009582.JPEG': u'earthstar',
#  'ILSVRC2012_val_00041023.JPEG': u'crash helmet',
#  'ILSVRC2012_val_00028015.JPEG': u'gyromitra',
#  'ILSVRC2012_val_00043215.JPEG': u'megalith, megalithic structure',
#  'ILSVRC2012_val_00037898.JPEG': u'dugong, Dugong dugon',
#  'ILSVRC2012_val_00027168.JPEG': u'Welsh springer spaniel',
#  'ILSVRC2012_val_00045807.JPEG': u'isopod',
#  'ILSVRC2012_val_00007274.JPEG': u'confectionery, confectionary, candy store',
#  'ILSVRC2012_val_00009454.JPEG': u'earthstar',
#  'ILSVRC2012_val_00037698.JPEG': u'ostrich, Struthio camelus',
#  'ILSVRC2012_val_00039278.JPEG': u'assault rifle, assault gun',
#  'ILSVRC2012_val_00027919.JPEG': u'confectionery, confectionary, candy store',
#  'ILSVRC2012_val_00036357.JPEG': u'cannon',
#  'ILSVRC2012_val_00047791.JPEG': u'schooner',
#  'ILSVRC2012_val_00048278.JPEG': u'radio, wireless',
#  'ILSVRC2012_val_00005369.JPEG': u'ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus',
#  'ILSVRC2012_val_00035078.JPEG': u'goblet',
#  'ILSVRC2012_val_00047269.JPEG': u'cardigan',
#  'ILSVRC2012_val_00028607.JPEG': u'robin, American robin, Turdus migratorius',
#  'ILSVRC2012_val_00019097.JPEG': u'diamondback, diamondback rattlesnake, Crotalus adamanteus',
#  'ILSVRC2012_val_00020245.JPEG': u'swimming trunks, bathing trunks',
#  'ILSVRC2012_val_00026194.JPEG': u'golf ball',
#  'ILSVRC2012_val_00047373.JPEG': u'balloon',
#  'ILSVRC2012_val_00003431.JPEG': u'barn spider, Araneus cavaticus',
#  'ILSVRC2012_val_00035596.JPEG': u'running shoe',
#  'ILSVRC2012_val_00049697.JPEG': u'pizza, pizza pie',
#  'ILSVRC2012_val_00049825.JPEG': u'handkerchief, hankie, hanky, hankey',
#  'ILSVRC2012_val_00030446.JPEG': u'dishrag, dishcloth',
#  'ILSVRC2012_val_00037200.JPEG': u'agama',
#  'ILSVRC2012_val_00022499.JPEG': u'Chesapeake Bay retriever',
#  'ILSVRC2012_val_00048282.JPEG': u'wild boar, boar, Sus scrofa',
#  'ILSVRC2012_val_00027891.JPEG': u'racer, race car, racing car',
#  'ILSVRC2012_val_00021609.JPEG': u'binder, ring-binder',
#  'ILSVRC2012_val_00030065.JPEG': u'kelpie',
#  'ILSVRC2012_val_00002957.JPEG': u'tick',
#  'ILSVRC2012_val_00023236.JPEG': u'pinwheel',
#  'ILSVRC2012_val_00034916.JPEG': u'ibex, Capra ibex',
#  'ILSVRC2012_val_00038521.JPEG': u'cocktail shaker',
#  'ILSVRC2012_val_00041642.JPEG': u'Chihuahua',
#  'ILSVRC2012_val_00048103.JPEG': u'folding chair',
#  'ILSVRC2012_val_00021568.JPEG': u'sliding door',
#  'ILSVRC2012_val_00043704.JPEG': u'vault',
#  'ILSVRC2012_val_00028153.JPEG': u'platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus',
#  'ILSVRC2012_val_00040116.JPEG': u'German short-haired pointer',
#  'ILSVRC2012_val_00006951.JPEG': u'park bench',
#  'ILSVRC2012_val_00021883.JPEG': u'ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus',
#  'ILSVRC2012_val_00019764.JPEG': u'Shetland sheepdog, Shetland sheep dog, Shetland',
#  'ILSVRC2012_val_00045858.JPEG': u'night snake, Hypsiglena torquata',
#  'ILSVRC2012_val_00030822.JPEG': u'Norwich terrier',
#  'ILSVRC2012_val_00023679.JPEG': u'armadillo',
#  'ILSVRC2012_val_00016695.JPEG': u'common newt, Triturus vulgaris',
#  'ILSVRC2012_val_00018214.JPEG': u'palace',
#  'ILSVRC2012_val_00025524.JPEG': u'water ouzel, dipper',
#  'ILSVRC2012_val_00031444.JPEG': u'liner, ocean liner',
#  'ILSVRC2012_val_00035548.JPEG': u'tub, vat',
#  'ILSVRC2012_val_00008077.JPEG': u'water bottle',
#  'ILSVRC2012_val_00014385.JPEG': u'fire engine, fire truck',
#  'ILSVRC2012_val_00007839.JPEG': u'bullet train, bullet',
#  'ILSVRC2012_val_00046975.JPEG': u'American lobster, Northern lobster, Maine lobster, Homarus americanus',
#  'ILSVRC2012_val_00006148.JPEG': u'echidna, spiny anteater, anteater',
#  'ILSVRC2012_val_00017881.JPEG': u'kit fox, Vulpes macrotis',
#  'ILSVRC2012_val_00026537.JPEG': u'marmot',
#  'ILSVRC2012_val_00001223.JPEG': u'clumber, clumber spaniel',
#  'ILSVRC2012_val_00020637.JPEG': u'Sealyham terrier, Sealyham',
#  'ILSVRC2012_val_00045281.JPEG': u'red-breasted merganser, Mergus serrator',
#  'ILSVRC2012_val_00001873.JPEG': u'cricket',
#  'ILSVRC2012_val_00030501.JPEG': u'hoopskirt, crinoline',
#  'ILSVRC2012_val_00035652.JPEG': u'chiffonier, commode',
#  'ILSVRC2012_val_00045192.JPEG': u'conch',
#  'ILSVRC2012_val_00044975.JPEG': u'ostrich, Struthio camelus',
#  'ILSVRC2012_val_00015203.JPEG': u'grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus',
#  'ILSVRC2012_val_00035612.JPEG': u'spider monkey, Ateles geoffroyi',
#  'ILSVRC2012_val_00048835.JPEG': u'stethoscope',
#  'ILSVRC2012_val_00025209.JPEG': u'ice cream, icecream',
#  'ILSVRC2012_val_00033581.JPEG': u'Mexican hairless',
#  'ILSVRC2012_val_00046641.JPEG': u'minibus',
#  'ILSVRC2012_val_00024729.JPEG': u'Irish water spaniel',
#  'ILSVRC2012_val_00026313.JPEG': u'Norfolk terrier',
#  'ILSVRC2012_val_00018647.JPEG': u'dishwasher, dish washer, dishwashing machine',
#  'ILSVRC2012_val_00012257.JPEG': u'swing',
#  'ILSVRC2012_val_00033618.JPEG': u'coffeepot',
#  'ILSVRC2012_val_00034608.JPEG': u'Appenzeller',
#  'ILSVRC2012_val_00001858.JPEG': u'Doberman, Doberman pinscher',
#  'ILSVRC2012_val_00033735.JPEG': u'wig',
#  'ILSVRC2012_val_00006108.JPEG': u'wood rabbit, cottontail, cottontail rabbit',
#  'ILSVRC2012_val_00033599.JPEG': u'dugong, Dugong dugon',
#  'ILSVRC2012_val_00032545.JPEG': u'espresso',
#  'ILSVRC2012_val_00011691.JPEG': u'French horn, horn',
#  'ILSVRC2012_val_00028319.JPEG': u'ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin',
#  'ILSVRC2012_val_00027143.JPEG': u'table lamp',
#  'ILSVRC2012_val_00044459.JPEG': u'green mamba',
#  'ILSVRC2012_val_00013255.JPEG': u'cabbage butterfly',
#  'ILSVRC2012_val_00008825.JPEG': u'half track',
#  'ILSVRC2012_val_00033691.JPEG': u'bulbul',
#  'ILSVRC2012_val_00033402.JPEG': u'military uniform',
#  'ILSVRC2012_val_00035859.JPEG': u'flat-coated retriever',
#  'ILSVRC2012_val_00033329.JPEG': u'volleyball',
#  'ILSVRC2012_val_00025142.JPEG': u'wild boar, boar, Sus scrofa',
#  'ILSVRC2012_val_00027563.JPEG': u'sloth bear, Melursus ursinus, Ursus ursinus',
#  'ILSVRC2012_val_00008566.JPEG': u'African grey, African gray, Psittacus erithacus',
#  'ILSVRC2012_val_00007747.JPEG': u'abacus',
#  'ILSVRC2012_val_00010103.JPEG': u'projectile, missile',
#  'ILSVRC2012_val_00042956.JPEG': u'alp',
#  'ILSVRC2012_val_00042837.JPEG': u'perfume, essence',
#  'ILSVRC2012_val_00031030.JPEG': u'beer bottle',
#  'ILSVRC2012_val_00030573.JPEG': u'kit fox, Vulpes macrotis',
#  'ILSVRC2012_val_00013054.JPEG': u'limousine, limo',
#  'ILSVRC2012_val_00007057.JPEG': u'Pekinese, Pekingese, Peke',
#  'ILSVRC2012_val_00017679.JPEG': u'sax, saxophone',
#  'ILSVRC2012_val_00009559.JPEG': u'parachute, chute',
#  'ILSVRC2012_val_00035384.JPEG': u'freight car',
#  'ILSVRC2012_val_00040681.JPEG': u'wig',
#  'ILSVRC2012_val_00043765.JPEG': u'sea urchin',
#  'ILSVRC2012_val_00025960.JPEG': u'fiddler crab',
#  'ILSVRC2012_val_00016924.JPEG': u'bookcase',
#  'ILSVRC2012_val_00006944.JPEG': u'Bernese mountain dog',
#  'ILSVRC2012_val_00045158.JPEG': u'unicycle, monocycle',
#  'ILSVRC2012_val_00011129.JPEG': u'American chameleon, anole, Anolis carolinensis',
#  'ILSVRC2012_val_00031561.JPEG': u'hand-held computer, hand-held microcomputer',
#  'ILSVRC2012_val_00018955.JPEG': u'earthstar',
#  'ILSVRC2012_val_00005663.JPEG': u'night snake, Hypsiglena torquata',
#  'ILSVRC2012_val_00027558.JPEG': u'grasshopper, hopper',
#  'ILSVRC2012_val_00033527.JPEG': u'volcano',
#  'ILSVRC2012_val_00032382.JPEG': u'minibus',
#  'ILSVRC2012_val_00010618.JPEG': u'redshank, Tringa totanus',
#  'ILSVRC2012_val_00010989.JPEG': u'honeycomb',
#  'ILSVRC2012_val_00019453.JPEG': u'Granny Smith',
#  'ILSVRC2012_val_00038674.JPEG': u'groenendael',
#  'ILSVRC2012_val_00000504.JPEG': u'drilling platform, offshore rig',
#  'ILSVRC2012_val_00035226.JPEG': u'red wine',
#  'ILSVRC2012_val_00028090.JPEG': u'bell pepper',
#  'ILSVRC2012_val_00008537.JPEG': u'Dutch oven',
#  'ILSVRC2012_val_00015296.JPEG': u'horizontal bar, high bar',
#  'ILSVRC2012_val_00004749.JPEG': u'house finch, linnet, Carpodacus mexicanus',
#  'ILSVRC2012_val_00002440.JPEG': u'pineapple, ananas',
#  'ILSVRC2012_val_00043230.JPEG': u'pick, plectrum, plectron',
#  'ILSVRC2012_val_00020971.JPEG': u'ping-pong ball',
#  'ILSVRC2012_val_00024846.JPEG': u'plow, plough',
#  'ILSVRC2012_val_00000701.JPEG': u'swab, swob, mop',
#  'ILSVRC2012_val_00021006.JPEG': u'cheetah, chetah, Acinonyx jubatus',
#  'ILSVRC2012_val_00011740.JPEG': u"jack-o'-lantern",
#  'ILSVRC2012_val_00015896.JPEG': u'can opener, tin opener',
#  'ILSVRC2012_val_00023883.JPEG': u'hotdog, hot dog, red hot',
#  'ILSVRC2012_val_00021189.JPEG': u'carousel, carrousel, merry-go-round, roundabout, whirligig',
#  'ILSVRC2012_val_00030456.JPEG': u'thimble',
#  'ILSVRC2012_val_00040157.JPEG': u'water jug',
#  'ILSVRC2012_val_00021574.JPEG': u'flamingo',
#  'ILSVRC2012_val_00025389.JPEG': u'racer, race car, racing car',
#  'ILSVRC2012_val_00028753.JPEG': u'espresso',
#  'ILSVRC2012_val_00027867.JPEG': u'paper towel',
#  'ILSVRC2012_val_00010642.JPEG': u'plow, plough',
#  'ILSVRC2012_val_00049404.JPEG': u'marmoset',
#  'ILSVRC2012_val_00049503.JPEG': u'cellular telephone, cellular phone, cellphone, cell, mobile phone',
#  'ILSVRC2012_val_00032810.JPEG': u'computer keyboard, keypad',
#  'ILSVRC2012_val_00015953.JPEG': u'go-kart',
#  'ILSVRC2012_val_00039597.JPEG': u'castle',
#  'ILSVRC2012_val_00028519.JPEG': u'mongoose',
#  'ILSVRC2012_val_00035342.JPEG': u'swab, swob, mop',
#  'ILSVRC2012_val_00021481.JPEG': u'scale, weighing machine',
#  'ILSVRC2012_val_00000165.JPEG': u'broccoli',
#  'ILSVRC2012_val_00040110.JPEG': u'clog, geta, patten, sabot',
#  'ILSVRC2012_val_00010400.JPEG': u'kimono',
#  'ILSVRC2012_val_00042110.JPEG': u'wood rabbit, cottontail, cottontail rabbit',
#  'ILSVRC2012_val_00004278.JPEG': u'standard poodle',
#  'ILSVRC2012_val_00020753.JPEG': u'reflex camera',
#  'ILSVRC2012_val_00026305.JPEG': u'laptop, laptop computer',
#  'ILSVRC2012_val_00031686.JPEG': u'jaguar, panther, Panthera onca, Felis onca',
#  'ILSVRC2012_val_00003488.JPEG': u'sewing machine',
#  'ILSVRC2012_val_00010198.JPEG': u'walking stick, walkingstick, stick insect',
#  'ILSVRC2012_val_00030407.JPEG': u'American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier',
#  'ILSVRC2012_val_00032845.JPEG': u'perfume, essence',
#  'ILSVRC2012_val_00020841.JPEG': u'boxer',
#  'ILSVRC2012_val_00041396.JPEG': u'spotlight, spot',
#  'ILSVRC2012_val_00048565.JPEG': u'lab coat, laboratory coat',
#  'ILSVRC2012_val_00023910.JPEG': u'Norfolk terrier',
#  'ILSVRC2012_val_00040244.JPEG': u'American egret, great white heron, Egretta albus',
#  'ILSVRC2012_val_00035074.JPEG': u'ringlet, ringlet butterfly',
#  'ILSVRC2012_val_00016958.JPEG': u'lab coat, laboratory coat',
#  'ILSVRC2012_val_00030370.JPEG': u'Doberman, Doberman pinscher',
#  'ILSVRC2012_val_00043854.JPEG': u'ladybug, ladybeetle, lady beetle, ladybird, ladybird beetle',
#  'ILSVRC2012_val_00030130.JPEG': u'shower cap',
#  'ILSVRC2012_val_00041844.JPEG': u'Appenzeller',
#  'ILSVRC2012_val_00021452.JPEG': u'Maltese dog, Maltese terrier, Maltese',
#  'ILSVRC2012_val_00019078.JPEG': u'patas, hussar monkey, Erythrocebus patas',
#  'ILSVRC2012_val_00010427.JPEG': u'parachute, chute',
#  'ILSVRC2012_val_00010327.JPEG': u'monitor',
#  'ILSVRC2012_val_00011882.JPEG': u'ballpoint, ballpoint pen, ballpen, Biro',
#  'ILSVRC2012_val_00007892.JPEG': u'Bedlington terrier',
#  'ILSVRC2012_val_00042810.JPEG': u'Brittany spaniel',
#  'ILSVRC2012_val_00043124.JPEG': u'shoji',
#  'ILSVRC2012_val_00025792.JPEG': u'combination lock',
#  'ILSVRC2012_val_00048952.JPEG': u'cock',
#  'ILSVRC2012_val_00028014.JPEG': u'oil filter',
#  'ILSVRC2012_val_00045000.JPEG': u'gondola',
#  'ILSVRC2012_val_00012265.JPEG': u'bonnet, poke bonnet',
#  'ILSVRC2012_val_00006984.JPEG': u'daisy',
#  'ILSVRC2012_val_00045120.JPEG': u'European fire salamander, Salamandra salamandra',
#  'ILSVRC2012_val_00026690.JPEG': u'umbrella',
#  'ILSVRC2012_val_00028093.JPEG': u'steel arch bridge',
#  'ILSVRC2012_val_00001875.JPEG': u'cowboy hat, ten-gallon hat',
#  'ILSVRC2012_val_00038256.JPEG': u'acorn',
#  'ILSVRC2012_val_00016828.JPEG': u'cellular telephone, cellular phone, cellphone, cell, mobile phone',
#  'ILSVRC2012_val_00025818.JPEG': u'barn spider, Araneus cavaticus',
#  'ILSVRC2012_val_00022264.JPEG': u'Blenheim spaniel',
#  'ILSVRC2012_val_00049947.JPEG': u'gong, tam-tam',
#  'ILSVRC2012_val_00044439.JPEG': u'car wheel',
#  'ILSVRC2012_val_00006714.JPEG': u'corn',
#  'ILSVRC2012_val_00032971.JPEG': u'gyromitra',
#  'ILSVRC2012_val_00022117.JPEG': u'sombrero',
#  'ILSVRC2012_val_00049260.JPEG': u'mud turtle',
#  'ILSVRC2012_val_00047805.JPEG': u'stopwatch, stop watch',
#  'ILSVRC2012_val_00045679.JPEG': u'necklace',
#  'ILSVRC2012_val_00027134.JPEG': u'American alligator, Alligator mississipiensis',
#  'ILSVRC2012_val_00045826.JPEG': u'chimpanzee, chimp, Pan troglodytes',
#  'ILSVRC2012_val_00049595.JPEG': u'ruffed grouse, partridge, Bonasa umbellus',
#  'ILSVRC2012_val_00015423.JPEG': u'combination lock',
#  'ILSVRC2012_val_00003500.JPEG': u'indri, indris, Indri indri, Indri brevicaudatus',
#  'ILSVRC2012_val_00030075.JPEG': u'hartebeest',
#  'ILSVRC2012_val_00000728.JPEG': u'guacamole',
#  'ILSVRC2012_val_00016554.JPEG': u'fiddler crab',
#  'ILSVRC2012_val_00005662.JPEG': u'German shepherd, German shepherd dog, German police dog, alsatian',
#  'ILSVRC2012_val_00044897.JPEG': u'Weimaraner',
#  'ILSVRC2012_val_00017751.JPEG': u'Dungeness crab, Cancer magister',
#  'ILSVRC2012_val_00006298.JPEG': u'suspension bridge',
#  'ILSVRC2012_val_00028726.JPEG': u'cuirass',
#  'ILSVRC2012_val_00001137.JPEG': u'Ibizan hound, Ibizan Podenco',
#  'ILSVRC2012_val_00047735.JPEG': u'cardoon',
#  'ILSVRC2012_val_00018116.JPEG': u'marimba, xylophone',
#  'ILSVRC2012_val_00049199.JPEG': u'mailbag, postbag',
#  'ILSVRC2012_val_00049543.JPEG': u'catamaran',
#  'ILSVRC2012_val_00049010.JPEG': u'vizsla, Hungarian pointer',
#  'ILSVRC2012_val_00036160.JPEG': u'desk',
#  'ILSVRC2012_val_00040266.JPEG': u'bee eater',
#  'ILSVRC2012_val_00045409.JPEG': u'sorrel',
#  'ILSVRC2012_val_00000652.JPEG': u'pier',
#  'ILSVRC2012_val_00040505.JPEG': u'flatworm, platyhelminth',
#  'ILSVRC2012_val_00011159.JPEG': u'swing',
#  'ILSVRC2012_val_00034477.JPEG': u'liner, ocean liner',
#  'ILSVRC2012_val_00049220.JPEG': u'polecat, fitch, foulmart, foumart, Mustela putorius',
#  'ILSVRC2012_val_00028785.JPEG': u'water tower',
#  'ILSVRC2012_val_00011536.JPEG': u'crossword puzzle, crossword',
#  'ILSVRC2012_val_00021864.JPEG': u'ant, emmet, pismire',
#  'ILSVRC2012_val_00045859.JPEG': u'basenji',
#  'ILSVRC2012_val_00020299.JPEG': u'paper towel',
#  'ILSVRC2012_val_00007675.JPEG': u'mosquito net',
#  'ILSVRC2012_val_00001007.JPEG': u'scorpion',
#  'ILSVRC2012_val_00012662.JPEG': u'skunk, polecat, wood pussy',
#  'ILSVRC2012_val_00000815.JPEG': u'sunglasses, dark glasses, shades',
#  'ILSVRC2012_val_00021834.JPEG': u'reel',
#  'ILSVRC2012_val_00034830.JPEG': u'can opener, tin opener',
#  'ILSVRC2012_val_00041885.JPEG': u'vending machine',
#  'ILSVRC2012_val_00008493.JPEG': u'steel arch bridge',
#  'ILSVRC2012_val_00006403.JPEG': u'green mamba',
#  'ILSVRC2012_val_00041775.JPEG': u'envelope',
#  'ILSVRC2012_val_00039650.JPEG': u'table lamp',
#  'ILSVRC2012_val_00015143.JPEG': u'lakeside, lakeshore',
#  'ILSVRC2012_val_00001663.JPEG': u'cocker spaniel, English cocker spaniel, cocker',
#  'ILSVRC2012_val_00047966.JPEG': u'pineapple, ananas',
#  'ILSVRC2012_val_00016521.JPEG': u'sunscreen, sunblock, sun blocker',
#  'ILSVRC2012_val_00014366.JPEG': u'fire engine, fire truck',
#  'ILSVRC2012_val_00006258.JPEG': u'cab, hack, taxi, taxicab',
#  'ILSVRC2012_val_00021282.JPEG': u'acoustic guitar',
#  'ILSVRC2012_val_00047093.JPEG': u"carpenter's kit, tool kit",
#  'ILSVRC2012_val_00022682.JPEG': u'cairn, cairn terrier',
#  'ILSVRC2012_val_00025996.JPEG': u'hippopotamus, hippo, river horse, Hippopotamus amphibius',
#  'ILSVRC2012_val_00005455.JPEG': u'book jacket, dust cover, dust jacket, dust wrapper',
#  'ILSVRC2012_val_00041878.JPEG': u'Labrador retriever',
#  'ILSVRC2012_val_00032513.JPEG': u'common iguana, iguana, Iguana iguana',
#  'ILSVRC2012_val_00037658.JPEG': u'bicycle-built-for-two, tandem bicycle, tandem',
#  'ILSVRC2012_val_00008348.JPEG': u'Welsh springer spaniel',
#  'ILSVRC2012_val_00024652.JPEG': u'Loafer',
#  'ILSVRC2012_val_00020285.JPEG': u'hamster',
#  'ILSVRC2012_val_00047712.JPEG': u'submarine, pigboat, sub, U-boat',
#  'ILSVRC2012_val_00017592.JPEG': u'English setter',
#  'ILSVRC2012_val_00018101.JPEG': u'feather boa, boa',
#  'ILSVRC2012_val_00018543.JPEG': u'hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa',
#  'ILSVRC2012_val_00040956.JPEG': u'crutch',
#  'ILSVRC2012_val_00037212.JPEG': u'orangutan, orang, orangutang, Pongo pygmaeus',
#  'ILSVRC2012_val_00012314.JPEG': u'lorikeet',
#  'ILSVRC2012_val_00003245.JPEG': u'unicycle, monocycle',
#  'ILSVRC2012_val_00012460.JPEG': u'Australian terrier',
#  'ILSVRC2012_val_00034498.JPEG': u'water jug',
#  'ILSVRC2012_val_00043145.JPEG': u'Siamese cat, Siamese',
#  'ILSVRC2012_val_00007537.JPEG': u'forklift',
#  'ILSVRC2012_val_00006154.JPEG': u'Windsor tie',
#  'ILSVRC2012_val_00040863.JPEG': u'brassiere, bra, bandeau',
#  'ILSVRC2012_val_00035565.JPEG': u'indigo bunting, indigo finch, indigo bird, Passerina cyanea',
#  'ILSVRC2012_val_00020276.JPEG': u'coffee mug',
#  'ILSVRC2012_val_00020573.JPEG': u'lemon',
#  'ILSVRC2012_val_00046870.JPEG': u'menu',
#  'ILSVRC2012_val_00012656.JPEG': u'bath towel',
#  'ILSVRC2012_val_00038184.JPEG': u'Granny Smith',
#  'ILSVRC2012_val_00005051.JPEG': u'school bus',
#  'ILSVRC2012_val_00036442.JPEG': u'platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus',
#  'ILSVRC2012_val_00020378.JPEG': u'ice lolly, lolly, lollipop, popsicle',
#  'ILSVRC2012_val_00048858.JPEG': u'English setter',
#  'ILSVRC2012_val_00030661.JPEG': u'barn',
#  'ILSVRC2012_val_00040404.JPEG': u'bald eagle, American eagle, Haliaeetus leucocephalus',
#  'ILSVRC2012_val_00022624.JPEG': u'dogsled, dog sled, dog sleigh',
#  'ILSVRC2012_val_00007556.JPEG': u'toilet tissue, toilet paper, bathroom tissue',
#  'ILSVRC2012_val_00034651.JPEG': u'limousine, limo',
#  'ILSVRC2012_val_00041673.JPEG': u'stinkhorn, carrion fungus',
#  'ILSVRC2012_val_00007504.JPEG': u'stretcher',
#  'ILSVRC2012_val_00027698.JPEG': u'notebook, notebook computer',
#  'ILSVRC2012_val_00037352.JPEG': u'beacon, lighthouse, beacon light, pharos',
#  'ILSVRC2012_val_00008590.JPEG': u'harvester, reaper',
#  'ILSVRC2012_val_00037500.JPEG': u'red-breasted merganser, Mergus serrator',
#  'ILSVRC2012_val_00018946.JPEG': u'torch',
#  'ILSVRC2012_val_00010406.JPEG': u'shopping cart',
#  'ILSVRC2012_val_00031115.JPEG': u'hoopskirt, crinoline',
#  'ILSVRC2012_val_00009081.JPEG': u'beaver',
#  'ILSVRC2012_val_00029524.JPEG': u'mantis, mantid',
#  'ILSVRC2012_val_00012286.JPEG': u'beer bottle',
#  'ILSVRC2012_val_00017008.JPEG': u'lionfish',
#  'ILSVRC2012_val_00007318.JPEG': u'French bulldog',
#  'ILSVRC2012_val_00010124.JPEG': u'four-poster',
#  'ILSVRC2012_val_00015349.JPEG': u'curly-coated retriever',
#  'ILSVRC2012_val_00046954.JPEG': u'tub, vat',
#  'ILSVRC2012_val_00039551.JPEG': u'studio couch, day bed',
#  'ILSVRC2012_val_00043280.JPEG': u'chainlink fence',
#  'ILSVRC2012_val_00023702.JPEG': u'collie',
#  'ILSVRC2012_val_00025535.JPEG': u'goldfinch, Carduelis carduelis',
#  'ILSVRC2012_val_00017879.JPEG': u'Shetland sheepdog, Shetland sheep dog, Shetland',
#  'ILSVRC2012_val_00000626.JPEG': u'picket fence, paling',
#  'ILSVRC2012_val_00028639.JPEG': u'lampshade, lamp shade',
#  'ILSVRC2012_val_00030327.JPEG': u'Saint Bernard, St Bernard',
#  'ILSVRC2012_val_00025054.JPEG': u'cinema, movie theater, movie theatre, movie house, picture palace',
#  'ILSVRC2012_val_00030799.JPEG': u'cheeseburger',
#  'ILSVRC2012_val_00032181.JPEG': u'curly-coated retriever',
#  'ILSVRC2012_val_00034859.JPEG': u'teapot',
#  'ILSVRC2012_val_00042282.JPEG': u'gondola',
#  'ILSVRC2012_val_00014927.JPEG': u'green lizard, Lacerta viridis',
#  'ILSVRC2012_val_00048331.JPEG': u'mailbag, postbag',
#  'ILSVRC2012_val_00045992.JPEG': u'chest',
#  'ILSVRC2012_val_00044022.JPEG': u'pick, plectrum, plectron',
#  'ILSVRC2012_val_00015317.JPEG': u'plastic bag',
#  'ILSVRC2012_val_00010674.JPEG': u'cliff dwelling',
#  'ILSVRC2012_val_00042711.JPEG': u'rapeseed',
#  'ILSVRC2012_val_00018413.JPEG': u'apiary, bee house',
#  'ILSVRC2012_val_00007983.JPEG': u'digital watch',
#  'ILSVRC2012_val_00042782.JPEG': u'knee pad',
#  'ILSVRC2012_val_00019860.JPEG': u'marimba, xylophone',
#  'ILSVRC2012_val_00047234.JPEG': u'hand blower, blow dryer, blow drier, hair dryer, hair drier',
#  'ILSVRC2012_val_00020372.JPEG': u'car mirror',
#  'ILSVRC2012_val_00006218.JPEG': u'king snake, kingsnake',
#  'ILSVRC2012_val_00011329.JPEG': u'mountain bike, all-terrain bike, off-roader',
#  'ILSVRC2012_val_00019096.JPEG': u'miniature pinscher',
#  'ILSVRC2012_val_00005117.JPEG': u'sulphur butterfly, sulfur butterfly',
#  'ILSVRC2012_val_00011448.JPEG': u'agama',
#  'ILSVRC2012_val_00016090.JPEG': u'ambulance',
#  'ILSVRC2012_val_00020353.JPEG': u'speedboat',
#  'ILSVRC2012_val_00020323.JPEG': u'warthog',
#  'ILSVRC2012_val_00021242.JPEG': u'sorrel',
#  'ILSVRC2012_val_00027677.JPEG': u'flat-coated retriever',
#  'ILSVRC2012_val_00010826.JPEG': u'American alligator, Alligator mississipiensis',
#  'ILSVRC2012_val_00000827.JPEG': u'notebook, notebook computer',
#  'ILSVRC2012_val_00010634.JPEG': u'triceratops',
#  'ILSVRC2012_val_00007381.JPEG': u'patio, terrace',
#  'ILSVRC2012_val_00016339.JPEG': u'yurt',
#  'ILSVRC2012_val_00018518.JPEG': u'paintbrush',
#  'ILSVRC2012_val_00030240.JPEG': u'Old English sheepdog, bobtail',
#  'ILSVRC2012_val_00023701.JPEG': u'warplane, military plane',
#  'ILSVRC2012_val_00029879.JPEG': u'cardigan',
#  'ILSVRC2012_val_00017565.JPEG': u'wood rabbit, cottontail, cottontail rabbit',
#  'ILSVRC2012_val_00031349.JPEG': u'minibus',
#  'ILSVRC2012_val_00036802.JPEG': u'Gila monster, Heloderma suspectum',
#  'ILSVRC2012_val_00010257.JPEG': u'shoe shop, shoe-shop, shoe store',
#  'ILSVRC2012_val_00024775.JPEG': u'toyshop',
#  'ILSVRC2012_val_00012917.JPEG': u"pajama, pyjama, pj's, jammies",
#  'ILSVRC2012_val_00001869.JPEG': u'Norfolk terrier',
#  'ILSVRC2012_val_00023255.JPEG': u'tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui',
#  'ILSVRC2012_val_00027568.JPEG': u'space heater',
#  'ILSVRC2012_val_00040957.JPEG': u'sombrero',
#  'ILSVRC2012_val_00042763.JPEG': u'space heater',
#  'ILSVRC2012_val_00005543.JPEG': u'hamper',
#  'ILSVRC2012_val_00002791.JPEG': u'African grey, African gray, Psittacus erithacus',
#  'ILSVRC2012_val_00043927.JPEG': u'goose',
#  'ILSVRC2012_val_00010902.JPEG': u'Afghan hound, Afghan',
#  'ILSVRC2012_val_00012624.JPEG': u"plane, carpenter's plane, woodworking plane",
#  'ILSVRC2012_val_00017516.JPEG': u"plane, carpenter's plane, woodworking plane",
#  'ILSVRC2012_val_00042538.JPEG': u'carton',
#  'ILSVRC2012_val_00011895.JPEG': u'Tibetan terrier, chrysanthemum dog',
#  'ILSVRC2012_val_00022151.JPEG': u'weasel',
#  'ILSVRC2012_val_00048451.JPEG': u'patio, terrace',
#  'ILSVRC2012_val_00022017.JPEG': u'racer, race car, racing car',
#  'ILSVRC2012_val_00049957.JPEG': u'vending machine',
#  'ILSVRC2012_val_00019449.JPEG': u'Sussex spaniel',
#  'ILSVRC2012_val_00029005.JPEG': u'green lizard, Lacerta viridis',
#  'ILSVRC2012_val_00008831.JPEG': u'soap dispenser',
#  'ILSVRC2012_val_00010033.JPEG': u'soccer ball',
#  'ILSVRC2012_val_00039394.JPEG': u'dough',
#  'ILSVRC2012_val_00046776.JPEG': u'Tibetan mastiff',
#  'ILSVRC2012_val_00031100.JPEG': u'colobus, colobus monkey',
#  'ILSVRC2012_val_00004572.JPEG': u'bittern',
#  'ILSVRC2012_val_00029617.JPEG': u'grand piano, grand',
#  'ILSVRC2012_val_00017023.JPEG': u'crash helmet',
#  'ILSVRC2012_val_00040021.JPEG': u'daisy',
#  'ILSVRC2012_val_00025208.JPEG': u'armadillo',
#  'ILSVRC2012_val_00004241.JPEG': u'broccoli',
#  'ILSVRC2012_val_00044732.JPEG': u'coyote, prairie wolf, brush wolf, Canis latrans',
#  'ILSVRC2012_val_00046757.JPEG': u'tusker',
#  'ILSVRC2012_val_00033536.JPEG': u'dogsled, dog sled, dog sleigh',
#  'ILSVRC2012_val_00008716.JPEG': u'cradle',
#  'ILSVRC2012_val_00006918.JPEG': u'geyser',
#  'ILSVRC2012_val_00033278.JPEG': u'Lhasa, Lhasa apso',
#  'ILSVRC2012_val_00023381.JPEG': u'cicada, cicala',
#  'ILSVRC2012_val_00049917.JPEG': u'typewriter keyboard',
#  'ILSVRC2012_val_00003107.JPEG': u'minivan',
#  'ILSVRC2012_val_00007566.JPEG': u'bannister, banister, balustrade, balusters, handrail',
#  'ILSVRC2012_val_00025990.JPEG': u'jeep, landrover',
#  'ILSVRC2012_val_00044107.JPEG': u'cairn, cairn terrier',
#  'ILSVRC2012_val_00033706.JPEG': u'Gila monster, Heloderma suspectum',
#  'ILSVRC2012_val_00002363.JPEG': u'lemon',
#  'ILSVRC2012_val_00017422.JPEG': u'moped',
#  'ILSVRC2012_val_00009948.JPEG': u'zebra',
#  'ILSVRC2012_val_00046999.JPEG': u'Lakeland terrier',
#  'ILSVRC2012_val_00046386.JPEG': u'marimba, xylophone',
#  'ILSVRC2012_val_00043767.JPEG': u'wooden spoon',
#  'ILSVRC2012_val_00012144.JPEG': u'chest',
#  'ILSVRC2012_val_00021275.JPEG': u'menu',
#  'ILSVRC2012_val_00011672.JPEG': u'picket fence, paling',
#  'ILSVRC2012_val_00032827.JPEG': u'fig',
#  'ILSVRC2012_val_00005220.JPEG': u'boathouse',
#  'ILSVRC2012_val_00043184.JPEG': u'gasmask, respirator, gas helmet',
#  'ILSVRC2012_val_00033138.JPEG': u'crane',
#  'ILSVRC2012_val_00015041.JPEG': u'marmoset',
#  'ILSVRC2012_val_00037042.JPEG': u'grasshopper, hopper',
#  'ILSVRC2012_val_00021444.JPEG': u'power drill',
#  'ILSVRC2012_val_00004002.JPEG': u'picket fence, paling',
#  'ILSVRC2012_val_00006763.JPEG': u'brambling, Fringilla montifringilla',
#  'ILSVRC2012_val_00009227.JPEG': u'banana',
#  'ILSVRC2012_val_00013495.JPEG': u'microphone, mike',
#  'ILSVRC2012_val_00021074.JPEG': u'colobus, colobus monkey',
#  'ILSVRC2012_val_00028927.JPEG': u'sleeping bag',
#  'ILSVRC2012_val_00049754.JPEG': u'space shuttle',
#  'ILSVRC2012_val_00046069.JPEG': u'loggerhead, loggerhead turtle, Caretta caretta',
#  'ILSVRC2012_val_00041443.JPEG': u'buckle',
#  'ILSVRC2012_val_00028649.JPEG': u'ski',
#  'ILSVRC2012_val_00026885.JPEG': u'mantis, mantid',
#  'ILSVRC2012_val_00041957.JPEG': u'water buffalo, water ox, Asiatic buffalo, Bubalus bubalis',
#  'ILSVRC2012_val_00042608.JPEG': u'cardoon',
#  'ILSVRC2012_val_00006411.JPEG': u'pomegranate',
#  'ILSVRC2012_val_00035149.JPEG': u'cauliflower',
#  'ILSVRC2012_val_00041774.JPEG': u'violin, fiddle',
#  'ILSVRC2012_val_00044814.JPEG': u'Dungeness crab, Cancer magister',
#  'ILSVRC2012_val_00020883.JPEG': u'pay-phone, pay-station',
#  'ILSVRC2012_val_00011166.JPEG': u'refrigerator, icebox',
#  'ILSVRC2012_val_00022029.JPEG': u'proboscis monkey, Nasalis larvatus',
#  'ILSVRC2012_val_00037390.JPEG': u'bulletproof vest',
#  'ILSVRC2012_val_00036367.JPEG': u'catamaran',
#  'ILSVRC2012_val_00048321.JPEG': u'cup',
#  'ILSVRC2012_val_00022714.JPEG': u'paintbrush',
#  'ILSVRC2012_val_00011454.JPEG': u'patio, terrace',
#  'ILSVRC2012_val_00022428.JPEG': u'plastic bag',
#  'ILSVRC2012_val_00028261.JPEG': u'file, file cabinet, filing cabinet',
#  'ILSVRC2012_val_00020345.JPEG': u'beer bottle',
#  'ILSVRC2012_val_00025817.JPEG': u'pinwheel',
#  'ILSVRC2012_val_00044565.JPEG': u'bittern',
#  'ILSVRC2012_val_00037521.JPEG': u'gyromitra',
#  'ILSVRC2012_val_00026029.JPEG': u'beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon',
#  'ILSVRC2012_val_00016563.JPEG': u'Christmas stocking',
#  'ILSVRC2012_val_00039668.JPEG': u'Irish terrier',
#  'ILSVRC2012_val_00007664.JPEG': u'hornbill',
#  'ILSVRC2012_val_00015008.JPEG': u'barn',
#  'ILSVRC2012_val_00036240.JPEG': u'Saint Bernard, St Bernard',
#  'ILSVRC2012_val_00045720.JPEG': u'briard',
#  'ILSVRC2012_val_00041185.JPEG': u'llama',
#  'ILSVRC2012_val_00011561.JPEG': u'Polaroid camera, Polaroid Land camera',
#  'ILSVRC2012_val_00047763.JPEG': u'volleyball',
#  'ILSVRC2012_val_00039144.JPEG': u'Tibetan terrier, chrysanthemum dog',
#  'ILSVRC2012_val_00003508.JPEG': u'solar dish, solar collector, solar furnace',
#  'ILSVRC2012_val_00004353.JPEG': u'tank, army tank, armored combat vehicle, armoured combat vehicle',
#  'ILSVRC2012_val_00008888.JPEG': u'vine snake',
#  'ILSVRC2012_val_00048676.JPEG': u'long-horned beetle, longicorn, longicorn beetle',
#  'ILSVRC2012_val_00031504.JPEG': u'water jug',
#  'ILSVRC2012_val_00025809.JPEG': u'green lizard, Lacerta viridis',
#  'ILSVRC2012_val_00011894.JPEG': u'hummingbird',
#  'ILSVRC2012_val_00010025.JPEG': u'cabbage butterfly',
#  'ILSVRC2012_val_00035269.JPEG': u'Dungeness crab, Cancer magister',
#  'ILSVRC2012_val_00024225.JPEG': u'loudspeaker, speaker, speaker unit, loudspeaker system, speaker system',
#  'ILSVRC2012_val_00003533.JPEG': u'suit, suit of clothes',
#  'ILSVRC2012_val_00016872.JPEG': u'centipede',
#  'ILSVRC2012_val_00028318.JPEG': u'cougar, puma, catamount, mountain lion, painter, panther, Felis concolor',
#  'ILSVRC2012_val_00043226.JPEG': u'mixing bowl',
#  'ILSVRC2012_val_00018747.JPEG': u'baboon',
#  'ILSVRC2012_val_00033541.JPEG': u'gar, garfish, garpike, billfish, Lepisosteus osseus',
#  'ILSVRC2012_val_00047470.JPEG': u'bittern',
#  'ILSVRC2012_val_00043736.JPEG': u'solar dish, solar collector, solar furnace',
#  'ILSVRC2012_val_00035143.JPEG': u'suspension bridge',
#  'ILSVRC2012_val_00049530.JPEG': u'hotdog, hot dog, red hot',
#  'ILSVRC2012_val_00044084.JPEG': u'web site, website, internet site, site',
#  'ILSVRC2012_val_00045129.JPEG': u'boa constrictor, Constrictor constrictor',
#  'ILSVRC2012_val_00013842.JPEG': u'padlock',
#  'ILSVRC2012_val_00040750.JPEG': u'hamster',
#  'ILSVRC2012_val_00005333.JPEG': u'water jug',
#  'ILSVRC2012_val_00015553.JPEG': u'electric fan, blower',
#  'ILSVRC2012_val_00040245.JPEG': u'macaque',
#  'ILSVRC2012_val_00025035.JPEG': u'robin, American robin, Turdus migratorius',
#  'ILSVRC2012_val_00013911.JPEG': u'white wolf, Arctic wolf, Canis lupus tundrarum',
#  'ILSVRC2012_val_00014441.JPEG': u'Scotch terrier, Scottish terrier, Scottie',
#  'ILSVRC2012_val_00023677.JPEG': u'anemone fish',
#  'ILSVRC2012_val_00003428.JPEG': u'wing',
#  'ILSVRC2012_val_00006222.JPEG': u'dam, dike, dyke',
#  'ILSVRC2012_val_00004739.JPEG': u'velvet',
#  'ILSVRC2012_val_00035549.JPEG': u'sea urchin',
#  'ILSVRC2012_val_00035170.JPEG': u'strawberry',
#  'ILSVRC2012_val_00049795.JPEG': u'necklace',
#  'ILSVRC2012_val_00004690.JPEG': u'bolete',
#  'ILSVRC2012_val_00029145.JPEG': u'fire screen, fireguard',
#  'ILSVRC2012_val_00028944.JPEG': u'dogsled, dog sled, dog sleigh',
#  'ILSVRC2012_val_00005228.JPEG': u'king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica',
#  'ILSVRC2012_val_00046741.JPEG': u'chimpanzee, chimp, Pan troglodytes',
#  'ILSVRC2012_val_00013664.JPEG': u'container ship, containership, container vessel',
#  'ILSVRC2012_val_00030114.JPEG': u'chain mail, ring mail, mail, chain armor, chain armour, ring armor, ring armour',
#  'ILSVRC2012_val_00006000.JPEG': u'miniskirt, mini',
#  'ILSVRC2012_val_00035902.JPEG': u'jackfruit, jak, jack',
#  'ILSVRC2012_val_00007593.JPEG': u'wardrobe, closet, press',
#  'ILSVRC2012_val_00048867.JPEG': u'washbasin, handbasin, washbowl, lavabo, wash-hand basin',
#  'ILSVRC2012_val_00016218.JPEG': u'paddle, boat paddle',
#  'ILSVRC2012_val_00037075.JPEG': u'collie',
#  'ILSVRC2012_val_00023437.JPEG': u'Siberian husky',
#  'ILSVRC2012_val_00038488.JPEG': u'robin, American robin, Turdus migratorius',
#  'ILSVRC2012_val_00018522.JPEG': u'barrow, garden cart, lawn cart, wheelbarrow',
#  'ILSVRC2012_val_00031988.JPEG': u'screw',
#  'ILSVRC2012_val_00015105.JPEG': u'wig',
#  'ILSVRC2012_val_00037043.JPEG': u'tricycle, trike, velocipede',
#  'ILSVRC2012_val_00049768.JPEG': u'ski mask',
#  'ILSVRC2012_val_00018850.JPEG': u'wig',
#  'ILSVRC2012_val_00004950.JPEG': u'minibus',
#  'ILSVRC2012_val_00002092.JPEG': u'vase',
#  'ILSVRC2012_val_00030774.JPEG': u'chocolate sauce, chocolate syrup',
#  'ILSVRC2012_val_00032590.JPEG': u'paddlewheel, paddle wheel',
#  'ILSVRC2012_val_00020003.JPEG': u'parachute, chute',
#  'ILSVRC2012_val_00008536.JPEG': u'Walker hound, Walker foxhound',
#  'ILSVRC2012_val_00004476.JPEG': u'oscilloscope, scope, cathode-ray oscilloscope, CRO',
#  'ILSVRC2012_val_00030091.JPEG': u'bassoon',
#  'ILSVRC2012_val_00017397.JPEG': u'basketball',
#  'ILSVRC2012_val_00014403.JPEG': u'chow, chow chow',
#  'ILSVRC2012_val_00011397.JPEG': u'poncho',
#  'ILSVRC2012_val_00048491.JPEG': u'colobus, colobus monkey',
#  'ILSVRC2012_val_00009751.JPEG': u'Loafer',
#  'ILSVRC2012_val_00014342.JPEG': u'collie',
#  'ILSVRC2012_val_00019483.JPEG': u'mushroom',
#  'ILSVRC2012_val_00025849.JPEG': u'digital clock',
#  'ILSVRC2012_val_00049302.JPEG': u'ambulance',
#  'ILSVRC2012_val_00013084.JPEG': u'mashed potato',
#  'ILSVRC2012_val_00000448.JPEG': u'harp',
#  'ILSVRC2012_val_00044397.JPEG': u'cowboy boot',
#  'ILSVRC2012_val_00025133.JPEG': u'tiger shark, Galeocerdo cuvieri',
#  'ILSVRC2012_val_00030721.JPEG': u'banded gecko',
#  'ILSVRC2012_val_00047845.JPEG': u'night snake, Hypsiglena torquata',
#  'ILSVRC2012_val_00005705.JPEG': u'cellular telephone, cellular phone, cellphone, cell, mobile phone',
#  'ILSVRC2012_val_00032052.JPEG': u'bikini, two-piece',
#  'ILSVRC2012_val_00008567.JPEG': u'pineapple, ananas',
#  'ILSVRC2012_val_00027697.JPEG': u'revolver, six-gun, six-shooter',
#  'ILSVRC2012_val_00016016.JPEG': u'flamingo',
#  'ILSVRC2012_val_00000715.JPEG': u'library',
#  'ILSVRC2012_val_00019343.JPEG': u'harmonica, mouth organ, harp, mouth harp',
#  'ILSVRC2012_val_00019040.JPEG': u'Dandie Dinmont, Dandie Dinmont terrier',
#  'ILSVRC2012_val_00029336.JPEG': u'whiptail, whiptail lizard',
#  'ILSVRC2012_val_00039212.JPEG': u'Tibetan terrier, chrysanthemum dog',
#  'ILSVRC2012_val_00036527.JPEG': u'leopard, Panthera pardus',
#  'ILSVRC2012_val_00002286.JPEG': u'sliding door',
#  'ILSVRC2012_val_00034404.JPEG': u'aircraft carrier, carrier, flattop, attack aircraft carrier',
#  'ILSVRC2012_val_00000888.JPEG': u'kite',
#  'ILSVRC2012_val_00024111.JPEG': u'cloak',
#  'ILSVRC2012_val_00011606.JPEG': u'soccer ball',
#  'ILSVRC2012_val_00048974.JPEG': u'Sussex spaniel',
#  'ILSVRC2012_val_00016885.JPEG': u'wall clock',
#  'ILSVRC2012_val_00004847.JPEG': u'sundial',
#  'ILSVRC2012_val_00042512.JPEG': u'barber chair',
#  'ILSVRC2012_val_00012125.JPEG': u'ear, spike, capitulum',
#  'ILSVRC2012_val_00007461.JPEG': u'thresher, thrasher, threshing machine',
#  'ILSVRC2012_val_00029547.JPEG': u'ice cream, icecream',
#  'ILSVRC2012_val_00036539.JPEG': u'French loaf',
#  'ILSVRC2012_val_00010911.JPEG': u'alligator lizard',
#  'ILSVRC2012_val_00009094.JPEG': u'file, file cabinet, filing cabinet',
#  'ILSVRC2012_val_00004035.JPEG': u'pick, plectrum, plectron',
#  'ILSVRC2012_val_00026085.JPEG': u'hornbill',
#  'ILSVRC2012_val_00047591.JPEG': u'Lakeland terrier',
#  'ILSVRC2012_val_00042570.JPEG': u'jaguar, panther, Panthera onca, Felis onca',
#  'ILSVRC2012_val_00011820.JPEG': u'leafhopper',
#  'ILSVRC2012_val_00013147.JPEG': u'scabbard',
#  'ILSVRC2012_val_00021614.JPEG': u'barrow, garden cart, lawn cart, wheelbarrow',
#  'ILSVRC2012_val_00047343.JPEG': u'agaric',
#  'ILSVRC2012_val_00017184.JPEG': u'lemon',
#  'ILSVRC2012_val_00035598.JPEG': u'American chameleon, anole, Anolis carolinensis',
#  'ILSVRC2012_val_00034645.JPEG': u'goblet',
#  'ILSVRC2012_val_00042199.JPEG': u'agaric',
#  'ILSVRC2012_val_00023851.JPEG': u'pool table, billiard table, snooker table',
#  'ILSVRC2012_val_00001574.JPEG': u'mitten',
#  'ILSVRC2012_val_00018209.JPEG': u'milk can',
#  'ILSVRC2012_val_00044487.JPEG': u'puck, hockey puck',
#  'ILSVRC2012_val_00024374.JPEG': u'mink',
#  'ILSVRC2012_val_00005892.JPEG': u'backpack, back pack, knapsack, packsack, rucksack, haversack',
#  'ILSVRC2012_val_00008648.JPEG': u'corn',
#  'ILSVRC2012_val_00024122.JPEG': u'meerkat, mierkat',
#  'ILSVRC2012_val_00000364.JPEG': u'mailbox, letter box',
#  'ILSVRC2012_val_00046865.JPEG': u'thatch, thatched roof',
#  'ILSVRC2012_val_00007601.JPEG': u'tarantula',
#  'ILSVRC2012_val_00003594.JPEG': u'book jacket, dust cover, dust jacket, dust wrapper',
#  'ILSVRC2012_val_00010643.JPEG': u'Rhodesian ridgeback',
#  'ILSVRC2012_val_00035733.JPEG': u'unicycle, monocycle',
#  'ILSVRC2012_val_00033151.JPEG': u'caldron, cauldron',
#  'ILSVRC2012_val_00013540.JPEG': u'electric guitar',
#  'ILSVRC2012_val_00002624.JPEG': u'patio, terrace',
#  'ILSVRC2012_val_00027627.JPEG': u'great grey owl, great gray owl, Strix nebulosa',
#  'ILSVRC2012_val_00020580.JPEG': u'mixing bowl',
#  'ILSVRC2012_val_00032039.JPEG': u'buckle',
#  'ILSVRC2012_val_00016982.JPEG': u'barbell',
#  'ILSVRC2012_val_00020404.JPEG': u'impala, Aepyceros melampus',
#  'ILSVRC2012_val_00033948.JPEG': u'boathouse',
#  'ILSVRC2012_val_00021348.JPEG': u'breastplate, aegis, egis',
#  'ILSVRC2012_val_00038947.JPEG': u'matchstick',
#  'ILSVRC2012_val_00013809.JPEG': u'sea lion',
#  'ILSVRC2012_val_00034073.JPEG': u'mousetrap',
#  'ILSVRC2012_val_00001717.JPEG': u'monarch, monarch butterfly, milkweed butterfly, Danaus plexippus',
#  'ILSVRC2012_val_00040009.JPEG': u'sports car, sport car',
#  'ILSVRC2012_val_00035097.JPEG': u'mobile home, manufactured home',
#  'ILSVRC2012_val_00000708.JPEG': u'Gordon setter',
#  'ILSVRC2012_val_00013460.JPEG': u'bee eater',
#  'ILSVRC2012_val_00044069.JPEG': u'shopping basket',
#  'ILSVRC2012_val_00038047.JPEG': u'titi, titi monkey',
#  'ILSVRC2012_val_00038697.JPEG': u'ladybug, ladybeetle, lady beetle, ladybird, ladybird beetle',
#  'ILSVRC2012_val_00048945.JPEG': u'pillow',
#  'ILSVRC2012_val_00000917.JPEG': u'binoculars, field glasses, opera glasses',
#  'ILSVRC2012_val_00041589.JPEG': u'consomme',
#  'ILSVRC2012_val_00035436.JPEG': u'chow, chow chow',
#  'ILSVRC2012_val_00040350.JPEG': u'viaduct',
#  'ILSVRC2012_val_00005713.JPEG': u'soccer ball',
#  'ILSVRC2012_val_00008864.JPEG': u'ice lolly, lolly, lollipop, popsicle',
#  'ILSVRC2012_val_00034058.JPEG': u'velvet',
#  'ILSVRC2012_val_00033908.JPEG': u'rock beauty, Holocanthus tricolor',
#  'ILSVRC2012_val_00023090.JPEG': u'killer whale, killer, orca, grampus, sea wolf, Orcinus orca',
#  'ILSVRC2012_val_00010164.JPEG': u'Gila monster, Heloderma suspectum',
#  'ILSVRC2012_val_00019015.JPEG': u'sombrero',
#  'ILSVRC2012_val_00007515.JPEG': u'assault rifle, assault gun',
#  'ILSVRC2012_val_00008233.JPEG': u'bubble',
#  'ILSVRC2012_val_00046783.JPEG': u'gibbon, Hylobates lar',
#  'ILSVRC2012_val_00028676.JPEG': u'tile roof',
#  'ILSVRC2012_val_00049946.JPEG': u'stethoscope',
#  'ILSVRC2012_val_00008719.JPEG': u'Komodo dragon, Komodo lizard, dragon lizard, giant lizard, Varanus komodoensis',
#  'ILSVRC2012_val_00027467.JPEG': u'fountain',
#  'ILSVRC2012_val_00028599.JPEG': u'terrapin',
#  'ILSVRC2012_val_00036011.JPEG': u'snorkel',
#  'ILSVRC2012_val_00012786.JPEG': u'recreational vehicle, RV, R.V.',
#  'ILSVRC2012_val_00004562.JPEG': u'bell cote, bell cot',
#  'ILSVRC2012_val_00015958.JPEG': u'tusker',
#  'ILSVRC2012_val_00023374.JPEG': u'thimble',
#  'ILSVRC2012_val_00017982.JPEG': u'lemon',
#  'ILSVRC2012_val_00043646.JPEG': u'garden spider, Aranea diademata',
#  'ILSVRC2012_val_00005018.JPEG': u'Mexican hairless',
#  'ILSVRC2012_val_00013717.JPEG': u'soup bowl',
#  'ILSVRC2012_val_00046880.JPEG': u'tow truck, tow car, wrecker',
#  'ILSVRC2012_val_00046143.JPEG': u'cocker spaniel, English cocker spaniel, cocker',
#  'ILSVRC2012_val_00018016.JPEG': u'capuchin, ringtail, Cebus capucinus',
#  'ILSVRC2012_val_00005969.JPEG': u'patas, hussar monkey, Erythrocebus patas',
#  'ILSVRC2012_val_00039194.JPEG': u'beer bottle',
#  'ILSVRC2012_val_00036878.JPEG': u'spotted salamander, Ambystoma maculatum',
#  'ILSVRC2012_val_00047350.JPEG': u'vulture',
#  'ILSVRC2012_val_00044170.JPEG': u'tarantula',
#  'ILSVRC2012_val_00021615.JPEG': u'wok',
#  'ILSVRC2012_val_00033144.JPEG': u'missile',
#  'ILSVRC2012_val_00041917.JPEG': u'quilt, comforter, comfort, puff',
#  'ILSVRC2012_val_00041120.JPEG': u'howler monkey, howler',
#  'ILSVRC2012_val_00019038.JPEG': u'robin, American robin, Turdus migratorius',
#  'ILSVRC2012_val_00019777.JPEG': u'banjo',
#  'ILSVRC2012_val_00048080.JPEG': u'Leonberg',
#  'ILSVRC2012_val_00025463.JPEG': u'African crocodile, Nile crocodile, Crocodylus niloticus',
#  'ILSVRC2012_val_00039426.JPEG': u'black swan, Cygnus atratus',
#  'ILSVRC2012_val_00041473.JPEG': u'Welsh springer spaniel',
#  'ILSVRC2012_val_00010616.JPEG': u'strawberry',
#  'ILSVRC2012_val_00008239.JPEG': u'palace',
#  'ILSVRC2012_val_00039885.JPEG': u'timber wolf, grey wolf, gray wolf, Canis lupus',
#  'ILSVRC2012_val_00021047.JPEG': u'pomegranate',
#  'ILSVRC2012_val_00039183.JPEG': u'necklace',
#  'ILSVRC2012_val_00049467.JPEG': u'toaster',
#  'ILSVRC2012_val_00043617.JPEG': u'trifle',
#  'ILSVRC2012_val_00040188.JPEG': u'orange',
#  'ILSVRC2012_val_00048110.JPEG': u'racket, racquet',
#  'ILSVRC2012_val_00040812.JPEG': u'beaker',
#  'ILSVRC2012_val_00001236.JPEG': u'patas, hussar monkey, Erythrocebus patas',
#  'ILSVRC2012_val_00004939.JPEG': u'church, church building',
#  'ILSVRC2012_val_00000170.JPEG': u'toy terrier',
#  'ILSVRC2012_val_00041013.JPEG': u'schooner',
#  'ILSVRC2012_val_00029080.JPEG': u'bullet train, bullet',
#  'ILSVRC2012_val_00008761.JPEG': u"potter's wheel",
#  'ILSVRC2012_val_00008029.JPEG': u'cello, violoncello',
#  'ILSVRC2012_val_00036134.JPEG': u'stretcher',
#  'ILSVRC2012_val_00035965.JPEG': u'cassette',
#  'ILSVRC2012_val_00029829.JPEG': u'marmot',
#  'ILSVRC2012_val_00009625.JPEG': u'damselfly',
#  'ILSVRC2012_val_00040567.JPEG': u'electric ray, crampfish, numbfish, torpedo',
#  'ILSVRC2012_val_00005661.JPEG': u'shower cap',
#  'ILSVRC2012_val_00000578.JPEG': u'dugong, Dugong dugon',
#  'ILSVRC2012_val_00004947.JPEG': u'American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier',
#  'ILSVRC2012_val_00030781.JPEG': u'lionfish',
#  'ILSVRC2012_val_00001608.JPEG': u'dugong, Dugong dugon',
#  'ILSVRC2012_val_00033061.JPEG': u'bell cote, bell cot',
#  'ILSVRC2012_val_00023549.JPEG': u'electric locomotive',
#  'ILSVRC2012_val_00032708.JPEG': u'hook, claw',
#  'ILSVRC2012_val_00024399.JPEG': u'Chesapeake Bay retriever',
#  'ILSVRC2012_val_00049389.JPEG': u'snow leopard, ounce, Panthera uncia',
#  'ILSVRC2012_val_00025838.JPEG': u'fire engine, fire truck',
#  'ILSVRC2012_val_00041997.JPEG': u'mountain tent',
#  'ILSVRC2012_val_00038622.JPEG': u'fox squirrel, eastern fox squirrel, Sciurus niger',
#  'ILSVRC2012_val_00024105.JPEG': u'mountain bike, all-terrain bike, off-roader',
#  'ILSVRC2012_val_00023964.JPEG': u'birdhouse',
#  'ILSVRC2012_val_00034338.JPEG': u'chain',
#  'ILSVRC2012_val_00049931.JPEG': u'basset, basset hound',
#  'ILSVRC2012_val_00011114.JPEG': u'knot',
#  'ILSVRC2012_val_00003628.JPEG': u'Irish water spaniel',
#  'ILSVRC2012_val_00027984.JPEG': u'wig',
#  'ILSVRC2012_val_00036190.JPEG': u'thunder snake, worm snake, Carphophis amoenus',
#  'ILSVRC2012_val_00007029.JPEG': u'Granny Smith',
#  'ILSVRC2012_val_00002504.JPEG': u'sea lion',
#  'ILSVRC2012_val_00014016.JPEG': u'lakeside, lakeshore',
#  'ILSVRC2012_val_00048056.JPEG': u'power drill',
#  'ILSVRC2012_val_00008141.JPEG': u'tricycle, trike, velocipede',
#  'ILSVRC2012_val_00004003.JPEG': u'orangutan, orang, orangutang, Pongo pygmaeus',
#  'ILSVRC2012_val_00047485.JPEG': u"plane, carpenter's plane, woodworking plane",
#  'ILSVRC2012_val_00018898.JPEG': u'chow, chow chow',
#  'ILSVRC2012_val_00005178.JPEG': u'oystercatcher, oyster catcher',
#  'ILSVRC2012_val_00039201.JPEG': u'weevil',
#  'ILSVRC2012_val_00031297.JPEG': u'red fox, Vulpes vulpes',
#  'ILSVRC2012_val_00041020.JPEG': u'scuba diver',
#  'ILSVRC2012_val_00005282.JPEG': u'hornbill',
#  'ILSVRC2012_val_00027959.JPEG': u'agaric',
#  'ILSVRC2012_val_00000146.JPEG': u'trombone',
#  'ILSVRC2012_val_00040966.JPEG': u'military uniform',
#  'ILSVRC2012_val_00015597.JPEG': u'chiton, coat-of-mail shell, sea cradle, polyplacophore',
#  'ILSVRC2012_val_00013852.JPEG': u'sandal',
#  'ILSVRC2012_val_00034075.JPEG': u'basenji',
#  'ILSVRC2012_val_00010709.JPEG': u'bull mastiff',
#  'ILSVRC2012_val_00004836.JPEG': u'artichoke, globe artichoke',
#  'ILSVRC2012_val_00030730.JPEG': u'bikini, two-piece',
#  'ILSVRC2012_val_00025436.JPEG': u'magnetic compass',
#  'ILSVRC2012_val_00019805.JPEG': u'sweatshirt',
#  'ILSVRC2012_val_00015826.JPEG': u'clog, geta, patten, sabot',
#  'ILSVRC2012_val_00014419.JPEG': u'greenhouse, nursery, glasshouse',
#  'ILSVRC2012_val_00030483.JPEG': u'kite',
#  'ILSVRC2012_val_00047792.JPEG': u'carousel, carrousel, merry-go-round, roundabout, whirligig',
#  'ILSVRC2012_val_00036726.JPEG': u'sax, saxophone',
#  'ILSVRC2012_val_00014779.JPEG': u'Brittany spaniel',
#  'ILSVRC2012_val_00014222.JPEG': u'thresher, thrasher, threshing machine',
#  'ILSVRC2012_val_00006011.JPEG': u'water snake',
#  'ILSVRC2012_val_00040742.JPEG': u'standard poodle',
#  'ILSVRC2012_val_00038996.JPEG': u'red wine',
#  'ILSVRC2012_val_00021201.JPEG': u'toilet tissue, toilet paper, bathroom tissue',
#  'ILSVRC2012_val_00011271.JPEG': u'solar dish, solar collector, solar furnace',
#  'ILSVRC2012_val_00014262.JPEG': u'space shuttle',
#  'ILSVRC2012_val_00035463.JPEG': u'go-kart',
#  'ILSVRC2012_val_00034937.JPEG': u'flute, transverse flute',
#  'ILSVRC2012_val_00043093.JPEG': u'rifle',
#  'ILSVRC2012_val_00035775.JPEG': u'dining table, board',
#  'ILSVRC2012_val_00036953.JPEG': u'titi, titi monkey',
#  'ILSVRC2012_val_00022290.JPEG': u'plate rack',
#  'ILSVRC2012_val_00050000.JPEG': u'llama',
#  'ILSVRC2012_val_00045956.JPEG': u'toy poodle',
#  'ILSVRC2012_val_00016850.JPEG': u'plastic bag',
#  'ILSVRC2012_val_00019511.JPEG': u'coucal',
#  'ILSVRC2012_val_00001512.JPEG': u'hot pot, hotpot',
#  'ILSVRC2012_val_00027556.JPEG': u'wild boar, boar, Sus scrofa',
#  'ILSVRC2012_val_00021193.JPEG': u'orange',
#  'ILSVRC2012_val_00048957.JPEG': u'green snake, grass snake',
#  'ILSVRC2012_val_00024798.JPEG': u'Arabian camel, dromedary, Camelus dromedarius',
#  'ILSVRC2012_val_00023913.JPEG': u'dalmatian, coach dog, carriage dog',
#  'ILSVRC2012_val_00025152.JPEG': u"plane, carpenter's plane, woodworking plane",
#  'ILSVRC2012_val_00004411.JPEG': u'Persian cat',
#  'ILSVRC2012_val_00013534.JPEG': u'washbasin, handbasin, washbowl, lavabo, wash-hand basin',
#  'ILSVRC2012_val_00043060.JPEG': u'dam, dike, dyke',
#  'ILSVRC2012_val_00034807.JPEG': u'indri, indris, Indri indri, Indri brevicaudatus',
#  'ILSVRC2012_val_00035015.JPEG': u'puck, hockey puck',
#  'ILSVRC2012_val_00018406.JPEG': u'clog, geta, patten, sabot',
#  'ILSVRC2012_val_00002645.JPEG': u'rock python, rock snake, Python sebae',
#  'ILSVRC2012_val_00013409.JPEG': u'armadillo',
#  'ILSVRC2012_val_00012563.JPEG': u'Band Aid',
#  'ILSVRC2012_val_00009766.JPEG': u'mushroom',
#  'ILSVRC2012_val_00042256.JPEG': u'paddlewheel, paddle wheel',
#  'ILSVRC2012_val_00014391.JPEG': u'skunk, polecat, wood pussy',
#  'ILSVRC2012_val_00022906.JPEG': u'carton',
#  'ILSVRC2012_val_00002289.JPEG': u'ballplayer, baseball player',
#  'ILSVRC2012_val_00026512.JPEG': u'warthog',
#  'ILSVRC2012_val_00009547.JPEG': u'Bouvier des Flandres, Bouviers des Flandres',
#  'ILSVRC2012_val_00005756.JPEG': u'nail',
#  'ILSVRC2012_val_00026069.JPEG': u'diaper, nappy, napkin',
#  'ILSVRC2012_val_00028086.JPEG': u'artichoke, globe artichoke',
#  'ILSVRC2012_val_00022655.JPEG': u'poncho',
#  'ILSVRC2012_val_00041938.JPEG': u'teapot',
#  'ILSVRC2012_val_00009995.JPEG': u'vault',
#  'ILSVRC2012_val_00037607.JPEG': u'sandbar, sand bar',
#  'ILSVRC2012_val_00002293.JPEG': u'home theater, home theatre',
#  'ILSVRC2012_val_00025839.JPEG': u'basketball',
#  'ILSVRC2012_val_00013477.JPEG': u'harmonica, mouth organ, harp, mouth harp',
#  'ILSVRC2012_val_00001546.JPEG': u'chimpanzee, chimp, Pan troglodytes',
#  'ILSVRC2012_val_00013885.JPEG': u'Saint Bernard, St Bernard',
#  'ILSVRC2012_val_00025368.JPEG': u'dishwasher, dish washer, dishwashing machine',
#  'ILSVRC2012_val_00006997.JPEG': u'pier',
#  'ILSVRC2012_val_00013192.JPEG': u'redshank, Tringa totanus',
#  'ILSVRC2012_val_00008449.JPEG': u'titi, titi monkey',
#  'ILSVRC2012_val_00022702.JPEG': u'diaper, nappy, napkin',
#  'ILSVRC2012_val_00031601.JPEG': u'Irish setter, red setter',
#  'ILSVRC2012_val_00009017.JPEG': u'tripod',
#  'ILSVRC2012_val_00027388.JPEG': u'plate rack',
#  'ILSVRC2012_val_00012363.JPEG': u'balance beam, beam',
#  'ILSVRC2012_val_00023083.JPEG': u'thimble',
#  'ILSVRC2012_val_00023868.JPEG': u'cloak',
#  'ILSVRC2012_val_00037426.JPEG': u'envelope',
#  'ILSVRC2012_val_00009943.JPEG': u'walking stick, walkingstick, stick insect',
#  'ILSVRC2012_val_00047748.JPEG': u'traffic light, traffic signal, stoplight',
#  'ILSVRC2012_val_00038234.JPEG': u'bathtub, bathing tub, bath, tub',
#  'ILSVRC2012_val_00013225.JPEG': u'folding chair',
#  'ILSVRC2012_val_00007186.JPEG': u'gas pump, gasoline pump, petrol pump, island dispenser',
#  'ILSVRC2012_val_00044750.JPEG': u'face powder',
#  'ILSVRC2012_val_00004977.JPEG': u'Gordon setter',
#  'ILSVRC2012_val_00033954.JPEG': u'hatchet',
#  'ILSVRC2012_val_00015087.JPEG': u'oscilloscope, scope, cathode-ray oscilloscope, CRO',
#  'ILSVRC2012_val_00041547.JPEG': u'wall clock',
#  'ILSVRC2012_val_00000124.JPEG': u'rock beauty, Holocanthus tricolor',
#  'ILSVRC2012_val_00049878.JPEG': u'Afghan hound, Afghan',
#  'ILSVRC2012_val_00025413.JPEG': u'violin, fiddle',
#  'ILSVRC2012_val_00046458.JPEG': u'potpie',
#  'ILSVRC2012_val_00029173.JPEG': u'polecat, fitch, foulmart, foumart, Mustela putorius',
#  'ILSVRC2012_val_00022723.JPEG': u'ladle',
#  'ILSVRC2012_val_00030851.JPEG': u'dhole, Cuon alpinus',
#  'ILSVRC2012_val_00000303.JPEG': u'tiger, Panthera tigris',
#  'ILSVRC2012_val_00015686.JPEG': u'green mamba',
#  'ILSVRC2012_val_00010468.JPEG': u'barbell',
#  'ILSVRC2012_val_00044521.JPEG': u'dumbbell',
#  'ILSVRC2012_val_00045196.JPEG': u'scabbard',
#  'ILSVRC2012_val_00028472.JPEG': u'rotisserie',
#  'ILSVRC2012_val_00047679.JPEG': u'hamper',
#  'ILSVRC2012_val_00010113.JPEG': u'Leonberg',
#  'ILSVRC2012_val_00031265.JPEG': u'military uniform',
#  'ILSVRC2012_val_00009643.JPEG': u'king penguin, Aptenodytes patagonica',
#  'ILSVRC2012_val_00005882.JPEG': u'moving van',
#  'ILSVRC2012_val_00044977.JPEG': u'Border terrier',
#  'ILSVRC2012_val_00019470.JPEG': u'chain',
#  'ILSVRC2012_val_00013198.JPEG': u'cup',
#  'ILSVRC2012_val_00013766.JPEG': u'screen, CRT screen',
#  'ILSVRC2012_val_00036906.JPEG': u'tricycle, trike, velocipede',
#  'ILSVRC2012_val_00042001.JPEG': u'pill bottle',
#  'ILSVRC2012_val_00005648.JPEG': u'groenendael',
#  'ILSVRC2012_val_00026205.JPEG': u'ski mask',
#  'ILSVRC2012_val_00026126.JPEG': u'police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria',
#  'ILSVRC2012_val_00035566.JPEG': u'Siamese cat, Siamese',
#  'ILSVRC2012_val_00004763.JPEG': u'Bernese mountain dog',
#  'ILSVRC2012_val_00040954.JPEG': u'menu',
#  'ILSVRC2012_val_00004794.JPEG': u'dome',
#  'ILSVRC2012_val_00017409.JPEG': u'green snake, grass snake',
#  'ILSVRC2012_val_00040672.JPEG': u'joystick',
#  'ILSVRC2012_val_00015830.JPEG': u'house finch, linnet, Carpodacus mexicanus',
#  'ILSVRC2012_val_00043886.JPEG': u'slide rule, slipstick',
#  'ILSVRC2012_val_00026850.JPEG': u'shower curtain',
#  'ILSVRC2012_val_00039967.JPEG': u'sea cucumber, holothurian',
#  'ILSVRC2012_val_00015552.JPEG': u'Gordon setter',
#  'ILSVRC2012_val_00011334.JPEG': u'catamaran',
#  'ILSVRC2012_val_00008600.JPEG': u'Loafer',
#  'ILSVRC2012_val_00025258.JPEG': u'sliding door',
#  'ILSVRC2012_val_00014572.JPEG': u'walking stick, walkingstick, stick insect',
#  'ILSVRC2012_val_00001987.JPEG': u'garden spider, Aranea diademata',
#  'ILSVRC2012_val_00048583.JPEG': u'ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin',
#  'ILSVRC2012_val_00010958.JPEG': u'digital watch',
#  'ILSVRC2012_val_00009696.JPEG': u'iron, smoothing iron',
#  'ILSVRC2012_val_00000066.JPEG': u'eel',
#  'ILSVRC2012_val_00011201.JPEG': u'flute, transverse flute',
#  'ILSVRC2012_val_00000594.JPEG': u'Appenzeller',
#  'ILSVRC2012_val_00041978.JPEG': u'studio couch, day bed',
#  'ILSVRC2012_val_00037211.JPEG': u'Irish water spaniel',
#  'ILSVRC2012_val_00008215.JPEG': u'manhole cover',
#  'ILSVRC2012_val_00038530.JPEG': u'street sign',
#  'ILSVRC2012_val_00000171.JPEG': u'stone wall',
#  'ILSVRC2012_val_00007745.JPEG': u'combination lock',
#  'ILSVRC2012_val_00003829.JPEG': u'lotion',
#  'ILSVRC2012_val_00049358.JPEG': u'guacamole',
#  'ILSVRC2012_val_00006940.JPEG': u'ram, tup',
#  'ILSVRC2012_val_00003490.JPEG': u'Samoyed, Samoyede',
#  'ILSVRC2012_val_00027760.JPEG': u'African crocodile, Nile crocodile, Crocodylus niloticus',
#  'ILSVRC2012_val_00007125.JPEG': u'sports car, sport car',
#  'ILSVRC2012_val_00035027.JPEG': u'Dandie Dinmont, Dandie Dinmont terrier',
#  'ILSVRC2012_val_00002657.JPEG': u'lab coat, laboratory coat',
#  'ILSVRC2012_val_00031091.JPEG': u'espresso maker',
#  'ILSVRC2012_val_00034208.JPEG': u'football helmet',
#  'ILSVRC2012_val_00007694.JPEG': u'oxygen mask',
#  'ILSVRC2012_val_00003578.JPEG': u'vestment',
#  'ILSVRC2012_val_00040847.JPEG': u'nipple',
#  'ILSVRC2012_val_00033778.JPEG': u'squirrel monkey, Saimiri sciureus',
#  'ILSVRC2012_val_00016350.JPEG': u'sulphur-crested cockatoo, Kakatoe galerita, Cacatua galerita',
#  'ILSVRC2012_val_00018935.JPEG': u'lycaenid, lycaenid butterfly',
#  'ILSVRC2012_val_00019297.JPEG': u'stage',
#  'ILSVRC2012_val_00044283.JPEG': u'CD player',
#  'ILSVRC2012_val_00034069.JPEG': u'Border collie',
#  'ILSVRC2012_val_00008151.JPEG': u'bald eagle, American eagle, Haliaeetus leucocephalus',
#  'ILSVRC2012_val_00031835.JPEG': u'coffeepot',
#  'ILSVRC2012_val_00012639.JPEG': u'black stork, Ciconia nigra',
#  'ILSVRC2012_val_00003002.JPEG': u'Airedale, Airedale terrier',
#  'ILSVRC2012_val_00023082.JPEG': u'soup bowl',
#  'ILSVRC2012_val_00019905.JPEG': u'tile roof',
#  'ILSVRC2012_val_00028445.JPEG': u'black and gold garden spider, Argiope aurantia',
#  'ILSVRC2012_val_00042145.JPEG': u'frying pan, frypan, skillet',
#  'ILSVRC2012_val_00005855.JPEG': u'bookshop, bookstore, bookstall',
#  'ILSVRC2012_val_00003042.JPEG': u'tiger cat',
#  'ILSVRC2012_val_00044508.JPEG': u'restaurant, eating house, eating place, eatery',
#  'ILSVRC2012_val_00018065.JPEG': u'lakeside, lakeshore',
#  'ILSVRC2012_val_00007631.JPEG': u'wild boar, boar, Sus scrofa',
#  'ILSVRC2012_val_00030238.JPEG': u'Airedale, Airedale terrier',
#  'ILSVRC2012_val_00016213.JPEG': u'library',
#  'ILSVRC2012_val_00044291.JPEG': u'military uniform',
#  'ILSVRC2012_val_00016160.JPEG': u'cockroach, roach',
#  'ILSVRC2012_val_00027266.JPEG': u'bell pepper',
#  'ILSVRC2012_val_00028604.JPEG': u'ruffed grouse, partridge, Bonasa umbellus',
#  'ILSVRC2012_val_00023480.JPEG': u'gar, garfish, garpike, billfish, Lepisosteus osseus',
#  'ILSVRC2012_val_00039441.JPEG': u'mud turtle',
#  'ILSVRC2012_val_00013447.JPEG': u'Rottweiler',
#  'ILSVRC2012_val_00004438.JPEG': u'vacuum, vacuum cleaner',
#  'ILSVRC2012_val_00016832.JPEG': u'church, church building',
#  'ILSVRC2012_val_00009705.JPEG': u'church, church building',
#  'ILSVRC2012_val_00013142.JPEG': u'vault',
#  'ILSVRC2012_val_00036923.JPEG': u'wooden spoon',
#  'ILSVRC2012_val_00021380.JPEG': u'notebook, notebook computer',
#  'ILSVRC2012_val_00014580.JPEG': u'bloodhound, sleuthhound',
#  'ILSVRC2012_val_00015372.JPEG': u'Persian cat',
#  'ILSVRC2012_val_00018752.JPEG': u'bolo tie, bolo, bola tie, bola',
#  'ILSVRC2012_val_00024277.JPEG': u'Pomeranian',
#  'ILSVRC2012_val_00025932.JPEG': u'maraca',
#  'ILSVRC2012_val_00033118.JPEG': u'acoustic guitar',
#  'ILSVRC2012_val_00020706.JPEG': u'freight car',
#  'ILSVRC2012_val_00044040.JPEG': u'hot pot, hotpot',
#  'ILSVRC2012_val_00026455.JPEG': u'earthstar',
#  'ILSVRC2012_val_00045843.JPEG': u'knot',
#  'ILSVRC2012_val_00005596.JPEG': u'jersey, T-shirt, tee shirt',
#  'ILSVRC2012_val_00027924.JPEG': u'goblet',
#  'ILSVRC2012_val_00044224.JPEG': u'Shih-Tzu',
#  'ILSVRC2012_val_00047307.JPEG': u'wig',
#  'ILSVRC2012_val_00007260.JPEG': u'horse cart, horse-cart',
#  'ILSVRC2012_val_00009827.JPEG': u'ptarmigan',
#  'ILSVRC2012_val_00014389.JPEG': u'beaver',
#  'ILSVRC2012_val_00016621.JPEG': u'American black bear, black bear, Ursus americanus, Euarctos americanus',
#  'ILSVRC2012_val_00011897.JPEG': u'radio, wireless',
#  'ILSVRC2012_val_00029282.JPEG': u'typewriter keyboard',
#  'ILSVRC2012_val_00011335.JPEG': u'perfume, essence',
#  'ILSVRC2012_val_00019922.JPEG': u'whippet',
#  'ILSVRC2012_val_00012114.JPEG': u'catamaran',
#  'ILSVRC2012_val_00018838.JPEG': u'shield, buckler',
#  'ILSVRC2012_val_00018042.JPEG': u'bicycle-built-for-two, tandem bicycle, tandem',
#  'ILSVRC2012_val_00044547.JPEG': u'passenger car, coach, carriage',
#  'ILSVRC2012_val_00024123.JPEG': u'hook, claw',
#  'ILSVRC2012_val_00014792.JPEG': u'gyromitra',
#  'ILSVRC2012_val_00048814.JPEG': u'little blue heron, Egretta caerulea',
#  'ILSVRC2012_val_00025401.JPEG': u'espresso maker',
#  'ILSVRC2012_val_00009557.JPEG': u'ski',
#  'ILSVRC2012_val_00046688.JPEG': u'bolo tie, bolo, bola tie, bola',
#  'ILSVRC2012_val_00015319.JPEG': u'fiddler crab',
#  'ILSVRC2012_val_00010534.JPEG': u'organ, pipe organ',
#  'ILSVRC2012_val_00000444.JPEG': u'ibex, Capra ibex',
#  'ILSVRC2012_val_00014427.JPEG': u'butcher shop, meat market',
#  'ILSVRC2012_val_00011127.JPEG': u'drumstick',
#  'ILSVRC2012_val_00031431.JPEG': u'half track',
#  'ILSVRC2012_val_00036004.JPEG': u'grey fox, gray fox, Urocyon cinereoargenteus',
#  'ILSVRC2012_val_00031474.JPEG': u'bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis',
#  'ILSVRC2012_val_00046556.JPEG': u'waffle iron',
#  'ILSVRC2012_val_00016979.JPEG': u'cup',
#  'ILSVRC2012_val_00033793.JPEG': u'stupa, tope',
#  'ILSVRC2012_val_00013076.JPEG': u'spider monkey, Ateles geoffroyi',
#  'ILSVRC2012_val_00045326.JPEG': u'laptop, laptop computer',
#  'ILSVRC2012_val_00014390.JPEG': u'bee',
#  'ILSVRC2012_val_00041136.JPEG': u'Christmas stocking',
#  'ILSVRC2012_val_00038595.JPEG': u'liner, ocean liner',
#  'ILSVRC2012_val_00001158.JPEG': u'toucan',
#  'ILSVRC2012_val_00011382.JPEG': u'leafhopper',
#  'ILSVRC2012_val_00024110.JPEG': u'bubble',
#  'ILSVRC2012_val_00048953.JPEG': u'paintbrush',
#  'ILSVRC2012_val_00017708.JPEG': u'pickup, pickup truck',
#  'ILSVRC2012_val_00009517.JPEG': u'catamaran',
#  'ILSVRC2012_val_00042646.JPEG': u'mountain tent',
#  'ILSVRC2012_val_00027810.JPEG': u'Saluki, gazelle hound',
#  'ILSVRC2012_val_00013355.JPEG': u'Cardigan, Cardigan Welsh corgi',
#  'ILSVRC2012_val_00030579.JPEG': u'curly-coated retriever',
#  'ILSVRC2012_val_00046657.JPEG': u'Bedlington terrier',
#  'ILSVRC2012_val_00018832.JPEG': u'Brittany spaniel',
#  'ILSVRC2012_val_00049324.JPEG': u'Italian greyhound',
#  'ILSVRC2012_val_00031702.JPEG': u'padlock',
#  'ILSVRC2012_val_00048986.JPEG': u'lipstick, lip rouge',
#  'ILSVRC2012_val_00022130.JPEG': u'convertible',
#  'ILSVRC2012_val_00026002.JPEG': u'thimble',
#  'ILSVRC2012_val_00009970.JPEG': u'screwdriver',
#  'ILSVRC2012_val_00048539.JPEG': u'wine bottle',
#  'ILSVRC2012_val_00037040.JPEG': u'sunglasses, dark glasses, shades',
#  'ILSVRC2012_val_00042101.JPEG': u'drilling platform, offshore rig',
#  'ILSVRC2012_val_00039491.JPEG': u'miniskirt, mini',
#  'ILSVRC2012_val_00044378.JPEG': u'robin, American robin, Turdus migratorius',
#  'ILSVRC2012_val_00023865.JPEG': u'sea slug, nudibranch',
#  'ILSVRC2012_val_00041230.JPEG': u'whiskey jug',
#  'ILSVRC2012_val_00043211.JPEG': u'coffee mug',
#  'ILSVRC2012_val_00040140.JPEG': u'English springer, English springer spaniel',
#  ...}

# %%
''.join(['0']*(8-len('453')))
# Out:
# '00000'

# %%
alexnet_results_dirpath = os.path.join(results_dirpath, 'AlexNet_full')
vgg_results_dirpath = os.path.join(results_dirpath, 'VGG_full')
googlenet_results_dirpath = os.path.join(results_dirpath, 'GoogLeNet_full')

all_pred_labels = {'AlexNet': imu.combine_checkpoint_results(alexnet_results_dirpath),
               'VGG': imu.combine_checkpoint_results(vgg_results_dirpath),
               'GoogLeNet': imu.combine_checkpoint_results(googlenet_results_dirpath)}

# %%
model_type = 'AlexNet'
pred_labels = all_pred_labels[model_type]
print 'Top-1 Accuracy for %s: %.2f%%'%(model_type, 100.*imu.compute_top_k_acc(ground_truth_labels, 
                                                                              pred_labels, 
                                                                              k=1))
print 'Top-5 Accuracy for %s: %.2f%%'%(model_type, 100.*imu.compute_top_k_acc(ground_truth_labels, 
                                                                              pred_labels, 
                                                                              k=5))
# Out:
# Top-1 Accuracy for AlexNet: 56.03%
# Top-5 Accuracy for AlexNet: 79.39%

# %%
inception_v3_results_dirpath = os.path.join(results_dirpath, 'GoogLeNetv3_full')
pred_labels = imu.combine_checkpoint_results(inception_v3_results_dirpath)

# %%
model_type = 'GoogLeNet inception v3'
print 'Top-1 Accuracy for %s: %.2f%%'%(model_type, 100.*imu.compute_top_k_acc(ground_truth_labels, 
                                                                              pred_labels, 
                                                                              k=1))
print 'Top-5 Accuracy for %s: %.2f%%'%(model_type, 100.*imu.compute_top_k_acc(ground_truth_labels, 
                                                                              pred_labels, 
                                                                              k=5))
# Out:
# Top-1 Accuracy for GoogLeNet inception v3: 1.43%
# Top-5 Accuracy for GoogLeNet inception v3: 7.32%

# %%
import pickle as pkl
d = pkl.load(open('/Users/babasarala/Desktop/results/ILSVRC2012_GoogLeNetv3_id_100.p', 'rb'))

# %%
d1 = pkl.load(open('/Users/babasarala/Desktop/evaluation/ILSVRC2012_val/GoogLeNetv3_full/ILSVRC2012_GoogLeNetv3_id_100.p'))

# %% [markdown]
# # Analyzing the ILSVR2012 Validation set with refactored classes

# %%
prune_filepath = os.path.join(cnn_dir, 'config/image_net_categories_animals_screenshots_devices_2016_05_04.json')
ground_truth_labels = imu.load_validation_ground_truth(ground_truth_filepath, 
                                                       mat_filepath, 
                                                       prune_filepath=prune_filepath)

# %%
alexnet_results_dirpath = os.path.join(results_dirpath, 'AlexNet_pruned_custom')
vgg_results_dirpath = os.path.join(results_dirpath, 'VGG_pruned_custom')
googlenet_results_dirpath = os.path.join(results_dirpath, 'GoogLeNet_pruned_custom')

all_pred_labels = {'AlexNet': imu.combine_checkpoint_results(alexnet_results_dirpath),
               'VGG': imu.combine_checkpoint_results(vgg_results_dirpath),
               'GoogLeNet': imu.combine_checkpoint_results(googlenet_results_dirpath)}

# %%
# recover the label names
prune_mappings = json.load(open(prune_filepath, 'rb'))
label_names = set([])
for imagenet_label, pruned_label in prune_mappings.iteritems():
    label_names.add(pruned_label)
label_names = list(label_names)

# %%
model_type = 'GoogLeNet'
pred_labels = all_pred_labels[model_type]
print 'Accuracy for %s on custom classes: %.2f%%'%(model_type, 
                                                   100.*imu.compute_top_k_acc(ground_truth_labels, 
                                                                              pred_labels, 
                                                                              k=1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1d9c573d37eb> in <module>()
#       1 model_type = 'GoogLeNet'
# ----> 2 pred_labels = all_pred_labels[model_type]
#       3 print 'Accuracy for %s on custom classes: %.2f%%'%(model_type,
#       4                                                    100.*imu.compute_top_k_acc(ground_truth_labels,
#       5                                                                               pred_labels,
#
# NameError: name 'all_pred_labels' is not defined

# %%
conf_mat, clf_report = imu.compute_metrics(ground_truth_labels, pred_labels, labels=label_names)
print label_names
print clf_report
# Out:
# [u'wildlife', u'other', u'screenshots', u'devices', u'furry_friends']
#              precision    recall  f1-score   support
#
#    wildlife       0.97      0.96      0.97     13600
#       other       0.97      0.98      0.98     29100
# screenshots       0.84      0.86      0.85        50
#     devices       0.80      0.73      0.76      1000
# furry_friends       0.96      0.98      0.97      6250
#
# avg / total       0.97      0.97      0.97     50000

# %%
mappings = {}
for idx, label in enumerate(label_names):
    mappings[idx] = label
    mappings[label] = idx

# %%
mappings
# Out:
# {0: u'wildlife',
#  1: u'other',
#  2: u'screenshots',
#  3: u'devices',
#  4: u'furry_friends',
#  u'devices': 3,
#  u'furry_friends': 4,
#  u'other': 1,
#  u'screenshots': 2,
#  u'wildlife': 0}

# %%
pred_labels[1]
# Out:
# [(u'wildlife', 0.92914779542479664),
#  (u'other', 0.054843743978835846),
#  (u'screenshots', 0.0001346807403024286),
#  (u'devices', 0.0016641851275380759),
#  (u'furry_friends', 0.013655060049131862)]

# %%
y_true = np.zeros((len(mappings)/2, len(ground_truth_labels)))
for idx, ground_truth_label in ground_truth_labels.iteritems():
    y_true[mappings[ground_truth_label], idx-1] = 1
y_true = y_true.T

# %%
y_prob = np.zeros((len(mappings)/2, len(pred_labels)))
for idx, pred_label in pred_labels.iteritems():
    for tup in pred_label:
        y_prob[mappings[tup[0]],idx-1] = tup[1]
y_prob = y_prob.T

# %%
y_true.shape
# Out:
# (50000, 5)

# %%
# Compute Precision-Recall and plot curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
import matplotlib.pyplot as plt

precision = dict()
recall = dict()
average_precision = dict()
n_classes = len(label_names)
for i in range(n_classes):
    precision[i], recall[i], threshs = precision_recall_curve(y_true[:, i],
                                                        y_prob[:, i])
    average_precision[i] = average_precision_score(y_true[:, i], y_prob[:, i])

# Plot Precision-Recall curve for each class
f = plt.figure(figsize=(12,10))
plt.clf()
for i in range(n_classes):
    plt.plot(recall[i], precision[i],
             label='Precision-recall curve of class: {0} (area = {1:0.2f})'
                   ''.format(mappings[i], average_precision[i]))

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve for ImageNet categories')
plt.legend(loc="lower left")
plt.show()

# %%
inception_v3_results_dirpath = os.path.join(results_dirpath, 'GoogLeNetv3_pruned_custom')
pred_labels = imu.combine_checkpoint_results(inception_v3_results_dirpath)
print 'Accuracy for %s on custom classes: %.2f%%'%(model_type, 
                                                   100.*imu.compute_top_k_acc(ground_truth_labels, 
                                                                              pred_labels, 
                                                                              k=1))
# Out:
# Accuracy for GoogLeNet on custom classes: 98.05%

# %%
conf_mat, clf_report = imu.compute_metrics(ground_truth_labels, pred_labels, labels=label_names)
print label_names
print clf_report
# Out:
# [u'wildlife', u'other', u'screenshots', u'devices', u'furry_friends']
#              precision    recall  f1-score   support
#
#    wildlife       0.99      0.98      0.98     13600
#       other       0.98      0.99      0.98     29100
# screenshots       0.80      0.96      0.87        50
#     devices       0.88      0.78      0.83      1000
# furry_friends       0.98      0.98      0.98      6250
#
# avg / total       0.98      0.98      0.98     50000
