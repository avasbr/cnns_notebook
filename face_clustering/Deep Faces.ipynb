# %%
import numpy as np
face_clustering_dirpath = '/Users/babasarala/Desktop/face_clustering_experiments/170/170_prod_1.0_images'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from cnns.core import CaffeVGGFace as vgg_face
from cnns.utils import cnn_utils as cu

model = vgg_face.CaffeVGGFace()
img_url = '/Users/babasarala/Desktop/1.jpg'

def hamid_function(img_url, model, layer_name='fc6'):
    img = cu.load_image(img_url, src='local')
    int_output = model.compute_intermediate_output(img, layer_name=layer_name)
    return int_output

# %%
hamid_function(img_url, model, 'fc6')
# Out:
# array([ -0.05598709,  -0.47233737,  -0.26586753, ...,  15.62666988,
#        -19.88749504,  -0.3597787 ], dtype=float32)

# %%
img_url = '/Users/babasarala/Desktop/1.jpg'

# %%
img = cu.load_image(img_url, src='local')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=302x325 at 0x139F9F250>

# %%
int_output = vgg_face_net.compute_intermediate_output(img, layer_name='fc6')

# %%
# Out:
# 4096
