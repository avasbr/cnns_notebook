# %%
from cnns.core import TorchOpenFace as tof
from cnns.utils import cnn_utils as cu
import cv2
import numpy as np
import pandas as pd
from cnns.core import SOMClusterer as scl
from sklearn.metrics.cluster import homogeneity_completeness_v_measure
from cnns.utils import clustering_utils as clu
import pickle as pkl
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_samples

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Playground

# %%
cluster_stats = scl_.compute_cluster_stats(cluster_df)

# %%
cluster_stats.columns
# Out:
# Index([u'avg_euclid_dist', u'cluster_idx', u'size', u'var'], dtype='object')

# %%
sorted_cluster_stats = cluster_stats.sort(columns=['avg_euclid_dist'])

# %%
cluster_df.columns
# Out:
# Index([u'f0', u'f1', u'f2', u'f3', u'f4', u'f5', u'f6', u'f7', u'f8', u'f9',
#        ...
#        u'f120', u'f121', u'f122', u'f123', u'f124', u'f125', u'f126', u'f127',
#        u'face_url', u'cluster_idx'],
#       dtype='object', length=130)

# %%
cluster_map = clu.get_map_from_dataframe(cluster_df, 'face_url', 'cluster_idx')
clu.visualize_clusters(cluster_map, '/Users/babasarala/Desktop/face_clustering/openface/%i_visualization.html'%user_id)

# %%
sorted_cluster_stats[sorted_cluster_stats['size'] > 10]
# Out:
#     avg_euclid_dist  cluster_idx  size       var
# 4          0.468043            4    43  0.111799
# 34         0.597210           34    14  0.176826
# 28         0.639599           28    13  0.197128
# 2          0.691272            2    24  0.237537
# 19         0.707702           19    18  0.247356
# 6          0.711931            6    28  0.258499
# 3          0.746288            3    14  0.276595
# 12         0.776627           12    24  0.305592

# %%
ed = sorted_cluster_stats['avg_euclid_dist'].values
var = sorted_cluster_stats['var'].values

# %%
plt.scatter(ed, var)
plt.show()
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Testing out Silhouette Samples

# %%
def visualize_silhouette_clusters(user_id, n_face_thresh=3, num_clusters=5, sil_coef_thresh=0):
    
    # paths
    results_dirpath = '/Users/babasarala/Desktop/face_clustering/openface_experiments'
    cluster_html_dirpath = '/Users/babasarala/Desktop/face_clustering/openface_experiments/cluster_htmls'
    cluster_html_filepath = '%s/%i_best_silhouette.html'%(cluster_html_dirpath, user_id)
    
    # get the feature vectors...
    img_urls, X = pkl.load(open('%s/%i_cnn_codes.p'%(results_dirpath, user_id), 'rb'))
    
    # ...cluster...
    scl_ = scl.SOMClusterer(img_urls, X)
    cluster_df = scl_.run()
    
    # filter clusters based on thresh and compute 
    num_faces_per_cluster = cluster_df['cluster_idx'].value_counts()
    num_faces_per_cluster = num_faces_per_cluster[num_faces_per_cluster >= n_faces_thresh]
    filt_cluster_idxs = num_faces_per_cluster.index.values
    filt_cluster_df = cluster_df[cluster_df['cluster_idx'].isin(filt_cluster_idxs)]

    X = filt_cluster_df[scl_.feat_cols].values
    labels = filt_cluster_df['cluster_idx'].values
    sil_coeffs = silhouette_samples(X, labels)
    filt_cluster_df['sil_coeff'] = sil_coeffs

    mean_sil_coeffs = []
    num_faces = []
    for cluster_idx in filt_cluster_idxs:
        curr_cluster = filt_cluster_df[filt_cluster_df['cluster_idx'] == cluster_idx]
        num_faces.append(len(curr_cluster))
        mean_sil_coeffs.append(np.mean(curr_cluster['sil_coeff'].values))
        

    cluster_stats = pd.DataFrame({'cluster_idx': filt_cluster_idxs, 
                                  'mean_sil_coeff': mean_sil_coeffs,
                                  'num_faces': num_faces})
    sorted_cluster_stats = cluster_stats.sort('num_faces', ascending=False)
    best_cluster_stats = sorted_cluster_stats[sorted_cluster_stats['mean_sil_coeff'] >= sil_coef_thresh]
    num_clusters = min(num_clusters, len(best_cluster_stats))
    
    top_idxs = best_cluster_stats.head(num_clusters)['cluster_idx'].values
    top_df = cluster_df[cluster_df['cluster_idx'].isin(top_idxs)]
    clustering_maps = clu.get_map_from_dataframe(top_df, 'face_url', 'cluster_idx')
    clu.visualize_clusters(clustering_maps, cluster_html_filepath)

# %%
def visualize_silhouette_clusters(user_id, n_face_thresh=3, sil_coef_thresh=0):
    
    # paths
    results_dirpath = '/Users/babasarala/Desktop/face_clustering/openface_experiments'
    cluster_html_dirpath = '/Users/babasarala/Desktop/face_clustering/openface_experiments/cluster_htmls'
    cluster_html_filepath = '%s/%i_best_silhouette.html'%(cluster_html_dirpath, user_id)
    
    # get the feature vectors...
    img_urls, X = pkl.load(open('%s/%i_cnn_codes.p'%(results_dirpath, user_id), 'rb'))
    
    # ...cluster...
    scl_ = scl.SOMClusterer(img_urls, X)
    cluster_df = scl_.run()
        
    # collect some metrics
    cluster_stats = scl_.create_cluster_stats(cluster_df)
    
    # visualize these clusters
    idxs = cluster_stats['cluster_idx'].values
    df = cluster_df[cluster_df['cluster_idx'].isin(idxs)]
    clustering_maps = clu.get_map_from_dataframe(df, 'face_url', 'cluster_idx')
    clu.visualize_clusters(clustering_maps, cluster_html_filepath)
    
    return cluster_stats

# %%
cluster_stats = visualize_silhouette_clusters(1946418)

# %%
cluster_stats
# Out:
#     avg_euclid_dist  cluster_idx  size       var  mean_sil_coeff
# 4          0.757709            6    45  0.296128        0.004810
# 3          0.486836            4    34  0.120997        0.047016
# 6          0.588512           14    30  0.176380        0.166631
# 1          0.653091            2    19  0.210686        0.024549
# 11         0.861164           25     9  0.352693        0.222854
# 16         0.690547           37     9  0.221213        0.091320
# 5          0.845591           10     9  0.327829        0.033778
# 8          0.509046           18     9  0.124221        0.122453
# 0          0.633221            0     7  0.222163        0.164048
# 12         0.484149           28     7  0.104996        0.094285
# 2          0.542716            3     7  0.134894        0.101804
# 10         0.585463           23     6  0.151085        0.035187
# 7          0.471310           17     6  0.100748        0.174737
# 14         0.475114           33     6  0.104267        0.282674
# 17         0.683854           40     6  0.201005        0.084530
# 9          0.518459           22     5  0.110406        0.126138
# 13         0.475053           31     5  0.097213        0.275790
# 15         0.671566           35     5  0.195847        0.026626
# 18         0.298618           45     4  0.034937        0.602045
# 23         0.584905           69     4  0.135346        0.044343
# 19         0.664325           49     3  0.167957        0.025409
# 20         0.666660           57     3  0.164476        0.004241
# 21         0.521299           60     3  0.091481        0.126667
# 22         0.570186           77     3  0.108982        0.267213

# %%
user_ids = [1946418, 8657185, 5626377, 5, 5692777, 3473194, 3928074, 4619758, 2685009, 1496616, 1341, 8, 34, 6007945]
for user_id in user_ids:
    try:
        cluster_stats = visualize_silhouette_clusters(user_id)
        
    except:
        print 'Something wrong w/ processing %i'%user_id

# %%
# filter clusters based on thresh and compute 
num_faces_per_cluster = cluster_df['cluster_idx'].value_counts()
num_faces_per_cluster = num_faces_per_cluster[num_faces_per_cluster >= n_faces_thresh]
filt_cluster_idxs = num_faces_per_cluster.index.values
filt_cluster_df = cluster_df[cluster_df['cluster_idx'].isin(filt_cluster_idxs)]

X = filt_cluster_df[scl_.feat_cols].values
labels = filt_cluster_df['cluster_idx'].values
sil_coeffs = silhouette_samples(X, labels)

# %%
cluster_sil_coeff = pd.DataFrame({'cluster_idx': filt_cluster_df['cluster_idx'].values, 
                                  'sil_coeff': sil_coeffs})

# %%
cluster_stats = cluster_sil_coeff.groupby('cluster_idx')['sil_coeff'].agg({'mean_sil_coeff':np.mean, 'num_faces':len}).reset_index()
# Out:
#     cluster_idx  mean_sil_coeff  num_faces
# 0             0        0.410976          6
# 1             1        0.036850          5
# 2             2        0.022369         21
# 3             3        0.059135         11
# 4             4       -0.045493         35
# 5             5       -0.118422         15
# 6             6        0.045952         42
# 7             8        0.131586          4
# 8             9        0.210541          3
# 9            10        0.174837          6
# 10           11       -0.062767          6
# 11           12       -0.045224          4
# 12           13        0.153913         35
# 13           16       -0.031239          5
# 14           17       -0.022763         16
# 15           21       -0.016770          6
# 16           23        0.333010          7
# 17           24        0.232416          3
# 18           25        0.164317          4
# 19           27        0.128865          3
# 20           28       -0.041202          9
# 21           29        0.067498         12
# 22           30        0.074679          7
# 23           32       -0.056258          9
# 24           34        0.166068         10
# 25           35        0.059514         13
# 26           36        0.051774          4
# 27           38       -0.047531          3
# 28           41        0.420722          6
# 29           42        0.119370          4
# 30           44       -0.201467          3
# 31           46        0.040829          3
# 32           51       -0.123484          4
# 33           59       -0.043636          3
# 34           75       -0.102980          3
# 35           83       -0.071792          3
# 36          101       -0.103365          3

# %%
pkl.dump()
