# %%
from cnns.utils import imagenet_utils as imu
from cnns.utils import training_utils as tu
from cnns.utils import cnn_utils as cu
import pandas as pd
import pickle as pkl

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cur = tu.start_psycon()

# %% [markdown]
# Creating true test sets

# %%
def generate_random_imagenet_set(cur, num_samples=10000):
    # look into faster ways of doing this
    query = 'SELECT iiu.img_url, iiu.internal_category \
             FROM imagenet_image_urls iiu \
             ORDER BY random() \
             LIMIT %i'%num_samples;
    records = tu.run_query(cur, query)
    df = pd.DataFrame(records, columns=['img_url', 'category'])
    return df
    
def collect_imagenet_test_set(cur):
    query = 'with full_and_val_set as (SELECT iiu.* \
    FROM imagenet_image_urls iiu \
    LEFT JOIN imagenet_validation_image_urls ivu ON iiu.img_url = ivu.img_url) \
    SELECT fvs.img_url, fvs.imagenet_category, fvs.internal_category \
    FROM full_and_val_set fvs \
    LEFT JOIN imagenet_training_image_urls itu \
    ON fvs.img_url = itu.img_url \
    WHERE itu.img_url IS NULL';
    records = tu.run_query(cur, query)
    
    df = pd.DataFrame(records, columns=['img_url', 'imagenet_category', 'category'])
    return df

def collect_everalbum_test_set(cur):
    query = "SELECT * FROM everalbum_image_urls"
    records = tu.run_query(cur, query)
    auth_tokens = {}
    data = []
    for record in records:
        user_id, mem_id, user_id, category = record
        if user_id not in auth_tokens:
            auth_tokens[user_id] = cu.get_auth_token(user_id)
        data.append({'img_url':'http://download-dot-maestro-prod.appspot.com/%i?auth_token=%s'
                        % (mem_id, auth_tokens[user_id]),
                     'category': category})
    
    df = pd.DataFrame(data)
    return df

# %%
imagenet_random_sample_df = generate_random_imagenet_set(cur, num_samples=100000)

# %%
imagenet_random_sample_df.to_csv('/Users/babasarala/Desktop/imagenet_random_sample.csv')

# %%
imagenet_df = collect_imagenet_test_set(cur) # set of images NOT used for training

# %%
imagenet_df
# Out:
#                                                   img_url  \
# 0       http://farm2.static.flickr.com/1213/1271491808...
# 1       http://farm2.static.flickr.com/1331/1050310100...
# 2       http://www.global-b2b-network.com/direct/dbima...
# 3       http://wangye.win.mofcom.gov.cn/www/8/wangye/i...
# 4       http://farm1.static.flickr.com/189/472483910_9...
# 5       http://www.tanimodimotoclub.it/foto-moto/foto-...
# 6       http://www.auto-motor.at/Motorrad/Motorraeder-...
# 7       http://www.logosfoundation.org/backgrounds/lib...
# 8       http://static.flickr.com/18/69786405_eb76e46db...
# 9       http://farm1.static.flickr.com/155/345985393_b...
# 10      http://lib.store.yahoo.net/lib/tpa/halloween02...
# 11      http://static.flickr.com/1082/1212533640_1d54e...
# 12        http://www.floranimal.ru/gallery/small/4010.jpg
# 13      http://pdubois.free.fr/mammiferes/thumbs/t_a01...
# 14      http://www.primeideas.com/DistributorCentralIm...
# 15      http://farm3.static.flickr.com/2242/1816869287...
# 16      http://www.gardenartisans.us/ProductImages/rom...
# 17      http://farm1.static.flickr.com/64/231300580_67...
# 18      http://farm2.static.flickr.com/1376/937905337_...
# 19      http://static.flickr.com/2249/2525040913_07d09...
# 20             http://www.spotanatomy.info/media/lego.jpg
# 21      http://farm3.static.flickr.com/2457/3756550712...
# 22      http://di1.shopping.com/images/pi/8d/db/4a/201...
# 23      http://pages.towson.edu/kopka/may8/flagpole_ce...
# 24      http://whatsthatbug.com/images/dung_beetle_mit...
# 25      http://farm2.static.flickr.com/1159/1345430493...
# 26      http://farm4.static.flickr.com/3283/2880094304...
# 27      http://farm3.static.flickr.com/2271/1933122488...
# 28      http://farm3.static.flickr.com/2417/2302833394...
# 29      http://static.flickr.com/250/453098099_118db47...
# ...                                                   ...
# 261041  http://farm2.static.flickr.com/1199/996375864_...
# 261042  http://www.gotpetsonline.com/pictures-gallery/...
# 261043  http://farm3.static.flickr.com/2137/2055401289...
# 261044  http://bp3.blogger.com/_VvQ7QuC2Eoo/RwwY3A-lB_...
# 261045  http://farm1.static.flickr.com/40/88050161_e74...
# 261046  http://farm1.static.flickr.com/12/17121218_3bf...
# 261047  http://www.elpalaciodehierro.com.mx/wcsstore/P...
# 261048  http://military.china.com/zh_cn/noads/11054186...
# 261049      http://ohioamphibians.com/Images/bullfrog.jpg
# 261050  http://ecx.images-amazon.com/images/I/41swqAdP...
# 261051  http://farm4.static.flickr.com/3025/2627579293...
# 261052             http://www.kimu.ws/images/sandbar2.jpg
# 261053  http://farm3.static.flickr.com/2279/2487378160...
# 261054  http://farm3.static.flickr.com/2022/2073284450...
# 261055  http://static.flickr.com/152/339449257_74eddfd...
# 261056  http://farm1.static.flickr.com/55/274162471_5a...
# 261057  http://farm4.static.flickr.com/3099/2750645100...
# 261058  http://www.bryandhughes.com/photos/herp/041206...
# 261059  http://www.chinafastener.biz/gb/picture/info/1...
# 261060  http://static.flickr.com/1313/530186910_2a9225...
# 261061  http://www.strollingguides.co.uk/photos/negs/t...
# 261062  http://static.flickr.com/2181/2096817512_96300...
# 261063  http://farm3.static.flickr.com/2056/2092804848...
# 261064  http://blissfullydomestic.com/wp-content/galle...
# 261065    http://tcusedparts.com/images/containership.jpg
# 261066  http://farm2.static.flickr.com/1321/1189102024...
# 261067  http://www.dogchannel.com/images/affenpinscher...
# 261068  http://vereine.freepage.de/psv-bad-ischl/Affen...
# 261069  http://farm3.static.flickr.com/2034/2246901176...
# 261070  http://aboutpedigreedogs.com/dog%20pictures/Au...
#
#                                         imagenet_category       category
# 0                               Pekinese, Pekingese, Peke  furry_friends
# 1                               Pekinese, Pekingese, Peke  furry_friends
# 2                                  motor scooter, scooter          other
# 3                                  motor scooter, scooter          other
# 4                                       Lhasa, Lhasa apso  furry_friends
# 5                                              neck brace          other
# 6                                              neck brace          other
# 7                                                 library          other
# 8                                                 library          other
# 9                                                 library          other
# 10                                        vending machine          other
# 11                                        vending machine          other
# 12                                       ibex, Capra ibex       wildlife
# 13                                       ibex, Capra ibex       wildlife
# 14                                            pill bottle          other
# 15                                                 sandal          other
# 16                                                sundial          other
# 17                     lion, king of beasts, Panthera leo       wildlife
# 18                hog, pig, grunter, squealer, Sus scrofa       wildlife
# 19                                                    eft       wildlife
# 20                                                  crane          other
# 21                                                  crane          other
# 22                                     screen, CRT screen        devices
# 23                                    flagpole, flagstaff          other
# 24                                            dung beetle       wildlife
# 25                                                  crane          other
# 26                                                  crane          other
# 27                                laptop, laptop computer        devices
# 28                                laptop, laptop computer        devices
# 29      dragonfly, darning needle, devil's darning nee...       wildlife
# ...                                                   ...            ...
# 261041                                             beagle  furry_friends
# 261042                                             beagle  furry_friends
# 261043                               cairn, cairn terrier  furry_friends
# 261044                               cairn, cairn terrier  furry_friends
# 261045                                  Eskimo dog, husky  furry_friends
# 261046                                  Eskimo dog, husky  furry_friends
# 261047                                               sock          other
# 261048                                            missile          other
# 261049                         bullfrog, Rana catesbeiana       wildlife
# 261050                                   pencil sharpener          other
# 261051  bannister, banister, balustrade, balusters, ha...          other
# 261052                                  sandbar, sand bar          other
# 261053                        tow truck, tow car, wrecker          other
# 261054                                    limousine, limo          other
# 261055                                             beagle  furry_friends
# 261056  African hunting dog, hyena dog, Cape hunting d...       wildlife
# 261057                                              screw          other
# 261058  sidewinder, horned rattlesnake, Crotalus cerastes       wildlife
# 261059                                              screw          other
# 261060                                          partridge       wildlife
# 261061     Madagascar cat, ring-tailed lemur, Lemur catta       wildlife
# 261062     Madagascar cat, ring-tailed lemur, Lemur catta       wildlife
# 261063                   sunscreen, sunblock, sun blocker          other
# 261064                   sunscreen, sunblock, sun blocker          other
# 261065    container ship, containership, container vessel          other
# 261066                              gibbon, Hylobates lar       wildlife
# 261067         affenpinscher, monkey pinscher, monkey dog  furry_friends
# 261068         affenpinscher, monkey pinscher, monkey dog  furry_friends
# 261069                                golfcart, golf cart          other
# 261070                                 Australian terrier  furry_friends
#
# [261071 rows x 3 columns]

# %%
imagenet_df['category'].value_counts()
# Out:
# other            126235
# wildlife          72019
# furry_friends     49638
# food               6186
# devices            5363
# documents          1098
# screenshots         532
# dtype: int64

# %%
curr_model = pkl.load(open('/Users/babasarala/repos/cnns/models/2016-08-16 14_26_08_L1_LR.p'))

# %%
custom_model_data = curr_model['complete_data'][['img_url', 'category']]

# %%
custom_model_data['category'].value_counts()
# Out:
# other          53265
# food           14338
# documents       1373
# whiteboards      168
# sketches          69
# dtype: int64

# %%
merged_set = pd.merge(imagenet_df, custom_model_data, on='img_url')
merged_set = merged_set.rename(columns={'category_x':'category'})x
merged_set['category'].value_counts()
# Out:
# other        10963
# food          3811
# documents     1080
# dtype: int64

# %%
merged_set.to_csv('/Users/babasarala/Desktop/settings_v1.7_test_set.csv')
